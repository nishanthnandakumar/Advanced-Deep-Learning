# %% [markdown]
# # Applied Deep Learning Tutorial
# contact: Mark.schutera@kit.edu
#
#
# # Deep Reinforcement Learning with Deep-Q-Network (DQN)
#
# ## Introduction
# In this tutorial, you will attempt to implement a Deep-Q-Network that is able to do a classic control. The approaches are build upon the paper by DeepMind: Playing Atari with Deep Reinforcement Learning [paper](https://www.cs.toronto.edu/~vmnih/docs/dqn.pdf), which first introduces the notion of a Deep Q-Network.
# <img src="graphics/atari_play.png" width="700"><br>
# <center> Fig. 1: Breakout environment of the Atari game </center>
#
# ## Core idea
# As you probably remember from the lecture, during trial and error we can learn a policy for our Atari game, and model it within our Q-matrix. This is done with a deep neural network. After training, this Q-matrix gives us an estimate of the expected reward when taking action a in state s: Q(s, a).
# Playing the action with the maximum Q-value in any given state is the same as playing optimal, or following a full exploitation strategy.
#
# ## OpenAI Gym
# [OpenAI Gym](https://gym.openai.com/docs/) is a library that can simulate a large number of reinforcement learning environments, including Atari games (these need to be installed additionaly). You will need Python 3.5+
#
# >pip install gym

# %% [markdown]
# ## Taking our cart pole on a first ride
# Now that you have gym installed you can load the 'Pendulum-v0' environment of Atari.

# %%
# Import the gym module
import gym

# %%
# Load the environment
env = gym.make('Pendulum-v0')

# Reset, it returns the starting frame
frame = env.reset()

for _ in range(100000):
    # Perform a random action, returns the new frame, reward and whether the game is over
    
    '''
    Implement to sample a random action from the action space within the loaded environment
    action = environment.action_space.sample()
    '''
    action = env.action_space.sample()
    observation, reward, is_done, info = env.step(action)
    print('observation: ', observation, 'reward: ', reward)
    if is_done: break
    env.render()

env.close()
# Out:
# observation:  [-0.13515454  0.99082453  1.07281116] reward:  -2.7484242888866386
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# <ipython-input-4-5d0f1102598f> in <module>()
#      16     print('observation: ', observation, 'reward: ', reward)
#      17     if is_done: break
# ---> 18     env.render()
#      19
#      20 env.close()
#
# /usr/local/lib/python3.7/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/pendulum.py in render(self, mode)
#      70     def render(self, mode='human'):
#      71         if self.viewer is None:
# ---> 72             from gym.envs.classic_control import rendering
#      73             self.viewer = rendering.Viewer(500, 500)
#      74             self.viewer.set_bounds(-2.2, 2.2, -2.2, 2.2)
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/rendering.py in <module>()
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in <module>()
#     242     # trickery is for circular import
#     243     _pyglet.gl = _sys.modules[__name__]
# --> 244     import pyglet.window
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/__init__.py in <module>()
#    1878 if not _is_pyglet_doc_run:
#    1879     pyglet.window = sys.modules[__name__]
# -> 1880     gl._create_shadow_window()
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     218
#     219     from pyglet.window import Window
# --> 220     _shadow_window = Window(width=1, height=1, visible=False)
#     221     _shadow_window.switch_to()
#     222
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     163                     self._event_handlers[message] = func
#     164
# --> 165         super(XlibWindow, self).__init__(*args, **kwargs)
#     166
#     167         global _can_detect_autorepeat
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     568
#     569         if not display:
# --> 570             display = pyglet.canvas.get_display()
#     571
#     572         if not screen:
#
# /usr/local/lib/python3.7/dist-packages/pyglet/canvas/__init__.py in get_display()
#      92
#      93     # Otherwise, create a new display and return it.
# ---> 94     return Display()
#      95
#      96
#
# /usr/local/lib/python3.7/dist-packages/pyglet/canvas/xlib.py in __init__(self, name, x_screen)
#     121         self._display = xlib.XOpenDisplay(name)
#     122         if not self._display:
# --> 123             raise NoSuchDisplayException('Cannot connect to "%s"' % name)
#     124
#     125         screen_count = xlib.XScreenCount(self._display)
#
# NoSuchDisplayException: Cannot connect to "None"

# %% [markdown]
# This already looks nice, yet the actions are random and thus it is time to better understand our environment. And to implement our Deep-Q-Network

# %%
# import the necessary libraries
import gym
import gym.spaces
import gym.wrappers
import numpy as np
import random
import pickle
from collections import deque
from keras.layers import Flatten, Dense
from keras import backend as K
from keras.models import Sequential, Model, load_model
from keras import optimizers

# %% [markdown]
# ## Observation
# The observation is made up of cos(theta), sin(theta) and theta dot.
# Theta is normalized between -pi and pi.
#
# ## Action
# Joint effort -2.0 to +2.0
# Write a function to discretize the continuous action space of the joint effort.

# %%
# define the action space
def create_action_bins(num_action_bins):
    '''
    Using linspace of numpy implement the action bins for the pendulum, when given the number of the action bins as argument
    actionbins = 
    '''
    actionbins = np.linspace(-2.0, 2.0, num_action_bins)
    return actionbins

# depending on the action, find the according actionbin 
# discretization of the continuous action space
def find_actionbin(action, actionbins):
    idx = (np.abs(actionbins - action)).argmin()

    return idx

# %% [markdown]
# ## Reward
# The reward is defined as
# > -(theta^2 + 0.1 x theta_dt^2 + 0.001 x action^2)
#
# What is the lowest expected cost? And what is the highest cost?
#
# -(pi^2 + 0.1 x 8^2 + 0.001 x 2^2) = -16.2736044
#
# -(0^2 + 0.1 x 0^2 + 0.001 x 0^2) = 0
#
# From this reward function, what is the goal of the agent?
# In essence, the goal is to remain at zero angle (vertical), with the least rotational velocity, and the least effort.
#
# For a hint have a look at the [wiki](https://github.com/openai/gym/wiki).

# %%
def train_model(memory, gamma=0.9):
    for state, action, reward, state_new in memory:
        
        # flatten state to make it compatible to our neural network
        flat_state_new = np.reshape(state_new, [1, 3])
        flat_state = np.reshape(state, [1, 3])

        # determine estimated reward given state s' after action a, 
        # combination of observed and predicted exploited reward.
        '''
        Implement the Q-function for the flat_state_new
        target = 
        '''
        target = reward + gamma * np.amax(model.predict(flat_state_new))
        # determine current expected agent rewards
        targetfull = model.predict(flat_state)
        
        # update current expected rewards with the emulated prediced reward
        targetfull[0][action] = target
        
        # Fit model based on emulation and prediction
        model.fit(flat_state, targetfull, epochs=1, verbose=0)

# %% [markdown]
# ## Deep Q Model
#
# As a reminder, this is our Q function.
# > Q(s, a) = r + gamma max_a'(Q(s, a'))
#
# The input of our neural network, our generalizable Q-matrix, will be the observation or the state of the pendulum.
# and the output will be the estimate of the reward taking the action a'. Gamma is the discount factor of the predicted reward in our next state. r is the reward

# %% [markdown]
# For our first network we will implement a DQN with keras:
#
# - Layer with 128 ReLU units
# - Layer with 64 ReLU units
# - 3 inputs and one output per action bin with linear activation function
# - Adam optimizer with learning rate 0.0002, beta_1 0.9 and beta_2 0.999
# - Loss mean squared error

# %%
# Define the Deep-Q-Network in keras

def build_model(num_output_nodes):
    model = Sequential()

    '''
    Design your model here (find description above)
    model. 
    model.
    model.
    '''
    
    '''
    Define the optimizer (find description above)
    adam = optimizers.
    '''
    
    '''
    define the loss (hint: search the web for keras loss and see description above)
    model.compile(loss=, optimizer=adam)
    '''

    model.add(Dense(128, input_shape=(3,), activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(num_output_nodes, activation='linear'))

    adam = optimizers.Adam(lr=0.0002, beta_1=0.9, beta_2=0.999)
    model.compile(loss='mse', optimizer=adam)

    return model

# %%
def run_episodes(epsilon, gamma, training_iterations, sequence_iterations):
    
    # These are hyperparameters to play around with, after your first run.
    epsilon_decay = 0.9999
    epsilon_min = 0.02
    steps_per_sequence = 250

    for epoch in range(0, training_iterations // sequence_iterations):
        for sequence_id in range(0, sequence_iterations):
            state = env.reset()
            memory = deque()
            
            total_reward = 0
            
            # Easy implementation of decaying exploration
            '''
            Given epsilon, epsilon_decay and epsilon_min implement a simple method for a decaying epsilon.
            
            Decay epsilon here, while bigger than epsilon_min
            if 
                            
            '''
            if epsilon > epsilon_min:
                epsilon = epsilon * epsilon_decay
            
            for i in range(0, steps_per_sequence):
                    
                '''
                Given epsilon implement a simple method for trading off exploration and exploitation
            
                Hint: For random values (use numpy) smaller than epsilon we want to explore
                
                if 
                    action = 
                
                Hint: For random values larger than epsilon we want to exploit
                
                else:
                    flat_state = np.reshape(state, [1, 3])
                    action = 
                '''

                if np.random.uniform() < epsilon:
                    action = env.action_space.sample()
                
                else:
                    flat_state = np.reshape(state, [1, 3])
                    action = np.amax(model.predict(flat_state))

                # determine action
                actionbin = find_actionbin(action, actionbinslist)
                action = actionbinslist[actionbin]
                action = np.array([action])

                # emulate the action in the simulation and observe the transition 
                # as well as the reward
                observation, reward, done, _ = env.step(action)
                total_reward += reward

                state_new = observation

                '''
                save transitions into memory
                Hint: The memory is used as an argument for the train_model function.
                
                memory.append((_, _, _, _))
                
                '''
                
                state = state_new
                
            # train model on the samples memories
            train_model(memory, gamma)
            
            print(epoch , ' epoch', sequence_id, ' sequence. Average reward = ', total_reward / steps_per_sequence, '. epsilon = ', epsilon)

# %% [markdown]
# ## Function for running the policy of our DQN after loading or training

# %%
def play_game(rounds):
    state = env.reset()
    totalreward = 0

    for _ in range(0, rounds):
        # Rendering for visualization
        env.render()

        flat_state = np.reshape(state, [1, 3])
        actionbin = np.argmax(model.predict(flat_state))

        action = actionbinslist[actionbin]
        action = np.array([action])

        observation, reward, done, _ = env.step(action)

        totalreward += reward

        state_new = observation
        state = state_new
        
    return totalreward

# %% [markdown]
# ## Train the DQN

# %%
env = gym.make('Pendulum-v0')

# These are hyperparameters to play around with

# iterations
training_iterations = 1000
sequence_iterations = 25

# epsilon (setting exploitation vs exploration)
epsilon = 1

# gamma (importance of predicted estimated reward)
gamma = 0.9

# Discretization settings for the action space
num_action_bins = 20
actionbinslist = create_action_bins(num_action_bins)



# Build model
model = build_model(num_action_bins)

run_episodes(epsilon, gamma, training_iterations, sequence_iterations)

'''
training takes super long, this is not efficient at all, how can we bypass this?
Hint: See cells in run pretrained model.

'''
# Out:
# 0  epoch 0  sequence. Average reward =  -6.256468222055881 . epsilon =  0.9999
# 0  epoch 1  sequence. Average reward =  -8.049552008920253 . epsilon =  0.9998000100000001
# 0  epoch 2  sequence. Average reward =  -8.244419313677705 . epsilon =  0.9997000299990001
# 0  epoch 3  sequence. Average reward =  -4.980299497287264 . epsilon =  0.9996000599960002
# 0  epoch 4  sequence. Average reward =  -5.057655084729925 . epsilon =  0.9995000999900007
# 0  epoch 5  sequence. Average reward =  -5.096677548873508 . epsilon =  0.9994001499800017
# 0  epoch 6  sequence. Average reward =  -8.564615719349902 . epsilon =  0.9993002099650037
# 0  epoch 7  sequence. Average reward =  -7.0783217684375375 . epsilon =  0.9992002799440072
# 0  epoch 8  sequence. Average reward =  -4.366898171674586 . epsilon =  0.9991003599160128
# 0  epoch 9  sequence. Average reward =  -5.2601717072195555 . epsilon =  0.9990004498800211
# 0  epoch 10  sequence. Average reward =  -4.064263665731455 . epsilon =  0.9989005498350332
# 0  epoch 11  sequence. Average reward =  -6.483646424992921 . epsilon =  0.9988006597800497
# 0  epoch 12  sequence. Average reward =  -8.167595086742393 . epsilon =  0.9987007797140718
# 0  epoch 13  sequence. Average reward =  -7.904885752658607 . epsilon =  0.9986009096361004
# 0  epoch 14  sequence. Average reward =  -5.883892669134063 . epsilon =  0.9985010495451367
# 0  epoch 15  sequence. Average reward =  -5.155368532679909 . epsilon =  0.9984011994401822
# 0  epoch 16  sequence. Average reward =  -5.65989683144641 . epsilon =  0.9983013593202382
# 0  epoch 17  sequence. Average reward =  -6.0291781961790765 . epsilon =  0.9982015291843062
# 0  epoch 18  sequence. Average reward =  -8.858388125204801 . epsilon =  0.9981017090313877
# 0  epoch 19  sequence. Average reward =  -5.274921339314394 . epsilon =  0.9980018988604846
# 0  epoch 20  sequence. Average reward =  -7.494278479179236 . epsilon =  0.9979020986705985
# 0  epoch 21  sequence. Average reward =  -8.925013401943088 . epsilon =  0.9978023084607315
# 0  epoch 22  sequence. Average reward =  -6.5257561246156 . epsilon =  0.9977025282298854
# 0  epoch 23  sequence. Average reward =  -6.555466670670074 . epsilon =  0.9976027579770624
# 0  epoch 24  sequence. Average reward =  -8.129394684455526 . epsilon =  0.9975029977012647
# 1  epoch 0  sequence. Average reward =  -6.311779094590127 . epsilon =  0.9974032474014946
# 1  epoch 1  sequence. Average reward =  -4.448363993189183 . epsilon =  0.9973035070767544
# 1  epoch 2  sequence. Average reward =  -5.943937514134175 . epsilon =  0.9972037767260468
# 1  epoch 3  sequence. Average reward =  -4.030729285138425 . epsilon =  0.9971040563483742
# 1  epoch 4  sequence. Average reward =  -5.193336368469819 . epsilon =  0.9970043459427393
# 1  epoch 5  sequence. Average reward =  -6.697279694579886 . epsilon =  0.9969046455081451
# 1  epoch 6  sequence. Average reward =  -5.217989639955904 . epsilon =  0.9968049550435942
# 1  epoch 7  sequence. Average reward =  -5.239374665785061 . epsilon =  0.9967052745480899
# 1  epoch 8  sequence. Average reward =  -4.821571921343893 . epsilon =  0.9966056040206351
# 1  epoch 9  sequence. Average reward =  -5.237496654851452 . epsilon =  0.9965059434602331
# 1  epoch 10  sequence. Average reward =  -7.397436987167604 . epsilon =  0.9964062928658871
# 1  epoch 11  sequence. Average reward =  -7.900371535266726 . epsilon =  0.9963066522366005
# 1  epoch 12  sequence. Average reward =  -8.535883400294466 . epsilon =  0.9962070215713769
# 1  epoch 13  sequence. Average reward =  -5.9244144766759765 . epsilon =  0.9961074008692198
# 1  epoch 14  sequence. Average reward =  -5.283500358486874 . epsilon =  0.9960077901291329
# 1  epoch 15  sequence. Average reward =  -5.684950592316376 . epsilon =  0.9959081893501199
# 1  epoch 16  sequence. Average reward =  -4.514955909897198 . epsilon =  0.995808598531185
# 1  epoch 17  sequence. Average reward =  -5.238472488067277 . epsilon =  0.9957090176713319
# 1  epoch 18  sequence. Average reward =  -8.47158243333315 . epsilon =  0.9956094467695648
# 1  epoch 19  sequence. Average reward =  -4.889312115417898 . epsilon =  0.9955098858248879
# 1  epoch 20  sequence. Average reward =  -3.7650400754502225 . epsilon =  0.9954103348363054
# 1  epoch 21  sequence. Average reward =  -6.121583646606208 . epsilon =  0.9953107938028217
# 1  epoch 22  sequence. Average reward =  -4.053578210023988 . epsilon =  0.9952112627234414
# 1  epoch 23  sequence. Average reward =  -5.65139670895725 . epsilon =  0.9951117415971691
# 1  epoch 24  sequence. Average reward =  -5.283837092908889 . epsilon =  0.9950122304230093
# 2  epoch 0  sequence. Average reward =  -4.53342533764725 . epsilon =  0.9949127291999671
# 2  epoch 1  sequence. Average reward =  -6.185109642040387 . epsilon =  0.9948132379270471
# 2  epoch 2  sequence. Average reward =  -7.0971744301880415 . epsilon =  0.9947137566032545
# 2  epoch 3  sequence. Average reward =  -7.944116006113709 . epsilon =  0.9946142852275941
# 2  epoch 4  sequence. Average reward =  -6.150330143612396 . epsilon =  0.9945148237990713
# 2  epoch 5  sequence. Average reward =  -4.896068787221324 . epsilon =  0.9944153723166914
# 2  epoch 6  sequence. Average reward =  -4.89116669182167 . epsilon =  0.9943159307794598
# 2  epoch 7  sequence. Average reward =  -4.506829631641727 . epsilon =  0.9942164991863819
# 2  epoch 8  sequence. Average reward =  -7.683077689157359 . epsilon =  0.9941170775364633
# 2  epoch 9  sequence. Average reward =  -6.96088168902187 . epsilon =  0.9940176658287097
# 2  epoch 10  sequence. Average reward =  -5.687413209852656 . epsilon =  0.9939182640621268
# 2  epoch 11  sequence. Average reward =  -8.410915564183732 . epsilon =  0.9938188722357206
# 2  epoch 12  sequence. Average reward =  -8.013257544106924 . epsilon =  0.993719490348497
# 2  epoch 13  sequence. Average reward =  -7.577952199232337 . epsilon =  0.9936201183994622
# 2  epoch 14  sequence. Average reward =  -6.024224651024926 . epsilon =  0.9935207563876223
# 2  epoch 15  sequence. Average reward =  -7.762299704475704 . epsilon =  0.9934214043119836
# 2  epoch 16  sequence. Average reward =  -4.843132986418073 . epsilon =  0.9933220621715524
# 2  epoch 17  sequence. Average reward =  -7.2480919217001345 . epsilon =  0.9932227299653352
# 2  epoch 18  sequence. Average reward =  -6.020402109655419 . epsilon =  0.9931234076923388
# 2  epoch 19  sequence. Average reward =  -4.378236499071591 . epsilon =  0.9930240953515695
# 2  epoch 20  sequence. Average reward =  -6.781179457345801 . epsilon =  0.9929247929420344
# 2  epoch 21  sequence. Average reward =  -5.917631438557198 . epsilon =  0.9928255004627402
# 2  epoch 22  sequence. Average reward =  -4.839424453034537 . epsilon =  0.992726217912694
# 2  epoch 23  sequence. Average reward =  -6.282037439030235 . epsilon =  0.9926269452909028
# 2  epoch 24  sequence. Average reward =  -5.371369100352312 . epsilon =  0.9925276825963737
# 3  epoch 0  sequence. Average reward =  -4.423523622482636 . epsilon =  0.9924284298281141
# 3  epoch 1  sequence. Average reward =  -4.492833723574187 . epsilon =  0.9923291869851313
# 3  epoch 2  sequence. Average reward =  -7.06855821887588 . epsilon =  0.9922299540664328
# 3  epoch 3  sequence. Average reward =  -5.641423485862469 . epsilon =  0.9921307310710261
# 3  epoch 4  sequence. Average reward =  -6.1811767488263705 . epsilon =  0.992031517997919
# 3  epoch 5  sequence. Average reward =  -8.402792944078756 . epsilon =  0.9919323148461192
# 3  epoch 6  sequence. Average reward =  -4.066534950364362 . epsilon =  0.9918331216146347
# 3  epoch 7  sequence. Average reward =  -8.043296871715567 . epsilon =  0.9917339383024733
# 3  epoch 8  sequence. Average reward =  -7.443383983123069 . epsilon =  0.991634764908643
# 3  epoch 9  sequence. Average reward =  -5.258237906338314 . epsilon =  0.9915356014321521
# 3  epoch 10  sequence. Average reward =  -6.110853770913945 . epsilon =  0.9914364478720089
# 3  epoch 11  sequence. Average reward =  -6.660041766072356 . epsilon =  0.9913373042272218
# 3  epoch 12  sequence. Average reward =  -8.4541505032215 . epsilon =  0.9912381704967991
# 3  epoch 13  sequence. Average reward =  -4.411115218673849 . epsilon =  0.9911390466797494
# 3  epoch 14  sequence. Average reward =  -5.642375020972534 . epsilon =  0.9910399327750814
# 3  epoch 15  sequence. Average reward =  -7.960325029329924 . epsilon =  0.9909408287818039
# 3  epoch 16  sequence. Average reward =  -4.502110031569631 . epsilon =  0.9908417346989258
# 3  epoch 17  sequence. Average reward =  -7.5995352378042424 . epsilon =  0.9907426505254558
# 3  epoch 18  sequence. Average reward =  -5.05970111315924 . epsilon =  0.9906435762604033
# 3  epoch 19  sequence. Average reward =  -5.308994894318771 . epsilon =  0.9905445119027773
# 3  epoch 20  sequence. Average reward =  -5.100467409047891 . epsilon =  0.990445457451587
# 3  epoch 21  sequence. Average reward =  -4.685006566055832 . epsilon =  0.9903464129058418
# 3  epoch 22  sequence. Average reward =  -6.359503791115029 . epsilon =  0.9902473782645512
# 3  epoch 23  sequence. Average reward =  -8.170325440253109 . epsilon =  0.9901483535267248
# 3  epoch 24  sequence. Average reward =  -5.7435717509424045 . epsilon =  0.9900493386913721
# 4  epoch 0  sequence. Average reward =  -6.736978320235648 . epsilon =  0.989950333757503
# 4  epoch 1  sequence. Average reward =  -6.561972455136339 . epsilon =  0.9898513387241272
# 4  epoch 2  sequence. Average reward =  -4.78339582954642 . epsilon =  0.9897523535902548
# 4  epoch 3  sequence. Average reward =  -7.05400915965919 . epsilon =  0.9896533783548958
# 4  epoch 4  sequence. Average reward =  -7.256791847875935 . epsilon =  0.9895544130170603
# 4  epoch 5  sequence. Average reward =  -4.152169915447169 . epsilon =  0.9894554575757586
# 4  epoch 6  sequence. Average reward =  -7.370482693369204 . epsilon =  0.9893565120300011
# 4  epoch 7  sequence. Average reward =  -4.625560771076931 . epsilon =  0.9892575763787981
# 4  epoch 8  sequence. Average reward =  -4.471691361320306 . epsilon =  0.9891586506211602
# 4  epoch 9  sequence. Average reward =  -4.366326692494984 . epsilon =  0.9890597347560981
# 4  epoch 10  sequence. Average reward =  -7.284694561792584 . epsilon =  0.9889608287826225
# 4  epoch 11  sequence. Average reward =  -7.706384830502821 . epsilon =  0.9888619326997442
# 4  epoch 12  sequence. Average reward =  -4.573032688113967 . epsilon =  0.9887630465064743
# 4  epoch 13  sequence. Average reward =  -6.67119664311069 . epsilon =  0.9886641702018236
# 4  epoch 14  sequence. Average reward =  -8.218326693022927 . epsilon =  0.9885653037848035
# 4  epoch 15  sequence. Average reward =  -6.46140835929012 . epsilon =  0.988466447254425
# 4  epoch 16  sequence. Average reward =  -6.985629826686738 . epsilon =  0.9883676006096995
# 4  epoch 17  sequence. Average reward =  -5.436234023048283 . epsilon =  0.9882687638496386
# 4  epoch 18  sequence. Average reward =  -4.467833896438363 . epsilon =  0.9881699369732536
# 4  epoch 19  sequence. Average reward =  -5.966912277247944 . epsilon =  0.9880711199795563
# 4  epoch 20  sequence. Average reward =  -4.4285242510680884 . epsilon =  0.9879723128675584
# 4  epoch 21  sequence. Average reward =  -4.068395465907527 . epsilon =  0.9878735156362717
# 4  epoch 22  sequence. Average reward =  -5.2652095055963715 . epsilon =  0.987774728284708
# 4  epoch 23  sequence. Average reward =  -6.020432198445345 . epsilon =  0.9876759508118795
# 4  epoch 24  sequence. Average reward =  -7.451888666722556 . epsilon =  0.9875771832167983
# 5  epoch 0  sequence. Average reward =  -8.325130601329349 . epsilon =  0.9874784254984766
# 5  epoch 1  sequence. Average reward =  -6.1979063418007385 . epsilon =  0.9873796776559268
# 5  epoch 2  sequence. Average reward =  -6.833646510133242 . epsilon =  0.9872809396881612
# 5  epoch 3  sequence. Average reward =  -4.104314552512864 . epsilon =  0.9871822115941924
# 5  epoch 4  sequence. Average reward =  -9.354627498886305 . epsilon =  0.987083493373033
# 5  epoch 5  sequence. Average reward =  -8.19543184527689 . epsilon =  0.9869847850236957
# 5  epoch 6  sequence. Average reward =  -6.692595403606524 . epsilon =  0.9868860865451933
# 5  epoch 7  sequence. Average reward =  -7.610789648410968 . epsilon =  0.9867873979365388
# 5  epoch 8  sequence. Average reward =  -4.9666098596250885 . epsilon =  0.9866887191967452
# 5  epoch 9  sequence. Average reward =  -8.076996011852335 . epsilon =  0.9865900503248255
# 5  epoch 10  sequence. Average reward =  -5.706010881118745 . epsilon =  0.986491391319793
# 5  epoch 11  sequence. Average reward =  -6.667772805423274 . epsilon =  0.9863927421806611
# 5  epoch 12  sequence. Average reward =  -8.320850281675318 . epsilon =  0.986294102906443
# 5  epoch 13  sequence. Average reward =  -8.102806927363702 . epsilon =  0.9861954734961524
# 5  epoch 14  sequence. Average reward =  -8.111615947965502 . epsilon =  0.9860968539488029
# 5  epoch 15  sequence. Average reward =  -4.9167224395750155 . epsilon =  0.985998244263408
# 5  epoch 16  sequence. Average reward =  -5.579004536677563 . epsilon =  0.9858996444389817
# 5  epoch 17  sequence. Average reward =  -5.787565988617942 . epsilon =  0.9858010544745378
# 5  epoch 18  sequence. Average reward =  -4.405353985411035 . epsilon =  0.9857024743690904
# 5  epoch 19  sequence. Average reward =  -5.7657074604240695 . epsilon =  0.9856039041216536
# 5  epoch 20  sequence. Average reward =  -6.724142339873229 . epsilon =  0.9855053437312414
# 5  epoch 21  sequence. Average reward =  -4.866741009505799 . epsilon =  0.9854067931968683
# 5  epoch 22  sequence. Average reward =  -6.135452725462636 . epsilon =  0.9853082525175486
# 5  epoch 23  sequence. Average reward =  -5.988241998629926 . epsilon =  0.9852097216922968
# 5  epoch 24  sequence. Average reward =  -7.340821544332067 . epsilon =  0.9851112007201276
# 6  epoch 0  sequence. Average reward =  -6.81214971467074 . epsilon =  0.9850126896000556
# 6  epoch 1  sequence. Average reward =  -6.1124803397372816 . epsilon =  0.9849141883310956
# 6  epoch 2  sequence. Average reward =  -6.035306007163634 . epsilon =  0.9848156969122625
# 6  epoch 3  sequence. Average reward =  -4.46876934817741 . epsilon =  0.9847172153425713
# 6  epoch 4  sequence. Average reward =  -7.966935921590735 . epsilon =  0.9846187436210371
# 6  epoch 5  sequence. Average reward =  -4.849145164953106 . epsilon =  0.9845202817466749
# 6  epoch 6  sequence. Average reward =  -4.441737774770419 . epsilon =  0.9844218297185002
# 6  epoch 7  sequence. Average reward =  -4.615948540913292 . epsilon =  0.9843233875355284
# 6  epoch 8  sequence. Average reward =  -5.297154376493072 . epsilon =  0.9842249551967749
# 6  epoch 9  sequence. Average reward =  -6.819689848677493 . epsilon =  0.9841265327012553
# 6  epoch 10  sequence. Average reward =  -6.563428738868382 . epsilon =  0.9840281200479851
# 6  epoch 11  sequence. Average reward =  -5.2691849379187765 . epsilon =  0.9839297172359803
# 6  epoch 12  sequence. Average reward =  -7.289126239247203 . epsilon =  0.9838313242642568
# 6  epoch 13  sequence. Average reward =  -9.179523074255046 . epsilon =  0.9837329411318304
# 6  epoch 14  sequence. Average reward =  -5.318269732294495 . epsilon =  0.9836345678377172
# 6  epoch 15  sequence. Average reward =  -7.054924868978254 . epsilon =  0.9835362043809335
# 6  epoch 16  sequence. Average reward =  -7.460215532712252 . epsilon =  0.9834378507604954
# 6  epoch 17  sequence. Average reward =  -6.065070687331199 . epsilon =  0.9833395069754194
# 6  epoch 18  sequence. Average reward =  -8.375733191564409 . epsilon =  0.9832411730247218
# 6  epoch 19  sequence. Average reward =  -6.915487053406384 . epsilon =  0.9831428489074193
# 6  epoch 20  sequence. Average reward =  -8.217719324030137 . epsilon =  0.9830445346225286
# 6  epoch 21  sequence. Average reward =  -6.3236526322575015 . epsilon =  0.9829462301690663
# 6  epoch 22  sequence. Average reward =  -7.01072352914462 . epsilon =  0.9828479355460494
# 6  epoch 23  sequence. Average reward =  -6.502807421082527 . epsilon =  0.9827496507524949
# 6  epoch 24  sequence. Average reward =  -8.19371681488059 . epsilon =  0.9826513757874197
# 7  epoch 0  sequence. Average reward =  -6.935095996854561 . epsilon =  0.982553110649841
# 7  epoch 1  sequence. Average reward =  -6.928766327256102 . epsilon =  0.982454855338776
# 7  epoch 2  sequence. Average reward =  -5.983617720928283 . epsilon =  0.9823566098532421
# 7  epoch 3  sequence. Average reward =  -5.909029852318731 . epsilon =  0.9822583741922568
# 7  epoch 4  sequence. Average reward =  -5.193117254341827 . epsilon =  0.9821601483548376
# 7  epoch 5  sequence. Average reward =  -4.942541674547407 . epsilon =  0.982061932340002
# 7  epoch 6  sequence. Average reward =  -4.808155844097778 . epsilon =  0.9819637261467681
# 7  epoch 7  sequence. Average reward =  -9.161779863703343 . epsilon =  0.9818655297741534
# 7  epoch 8  sequence. Average reward =  -8.542657752996346 . epsilon =  0.981767343221176
# 7  epoch 9  sequence. Average reward =  -8.622085316745126 . epsilon =  0.9816691664868539
# 7  epoch 10  sequence. Average reward =  -4.5798069838486875 . epsilon =  0.9815709995702052
# 7  epoch 11  sequence. Average reward =  -9.066047147157011 . epsilon =  0.9814728424702482
# 7  epoch 12  sequence. Average reward =  -6.970632720973806 . epsilon =  0.9813746951860012
# 7  epoch 13  sequence. Average reward =  -7.522630306604919 . epsilon =  0.9812765577164826
# 7  epoch 14  sequence. Average reward =  -7.618881070805254 . epsilon =  0.9811784300607109
# 7  epoch 15  sequence. Average reward =  -7.2934679896247845 . epsilon =  0.9810803122177049
# 7  epoch 16  sequence. Average reward =  -9.253601898622337 . epsilon =  0.9809822041864831
# 7  epoch 17  sequence. Average reward =  -7.122834708985494 . epsilon =  0.9808841059660645
# 7  epoch 18  sequence. Average reward =  -7.474318624066252 . epsilon =  0.9807860175554679
# 7  epoch 19  sequence. Average reward =  -4.84035234472558 . epsilon =  0.9806879389537123
# 7  epoch 20  sequence. Average reward =  -8.572264738039866 . epsilon =  0.9805898701598169
# 7  epoch 21  sequence. Average reward =  -4.7221172045142294 . epsilon =  0.9804918111728009
# 7  epoch 22  sequence. Average reward =  -5.111694212202406 . epsilon =  0.9803937619916837
# 7  epoch 23  sequence. Average reward =  -4.878396852216727 . epsilon =  0.9802957226154846
# 7  epoch 24  sequence. Average reward =  -5.911908804135593 . epsilon =  0.980197693043223
# 8  epoch 0  sequence. Average reward =  -6.421264923642317 . epsilon =  0.9800996732739187
# 8  epoch 1  sequence. Average reward =  -6.015943717145736 . epsilon =  0.9800016633065913
# 8  epoch 2  sequence. Average reward =  -4.002133187888405 . epsilon =  0.9799036631402607
# 8  epoch 3  sequence. Average reward =  -7.387766308891524 . epsilon =  0.9798056727739467
# 8  epoch 4  sequence. Average reward =  -6.310808975120164 . epsilon =  0.9797076922066693
# 8  epoch 5  sequence. Average reward =  -4.579295923825041 . epsilon =  0.9796097214374486
# 8  epoch 6  sequence. Average reward =  -7.762560247799049 . epsilon =  0.9795117604653049
# 8  epoch 7  sequence. Average reward =  -6.1440858773801 . epsilon =  0.9794138092892584
# 8  epoch 8  sequence. Average reward =  -5.668227605449007 . epsilon =  0.9793158679083295
# 8  epoch 9  sequence. Average reward =  -8.732433503198903 . epsilon =  0.9792179363215386
# 8  epoch 10  sequence. Average reward =  -5.3032245635151 . epsilon =  0.9791200145279065
# 8  epoch 11  sequence. Average reward =  -5.391618648302187 . epsilon =  0.9790221025264537
# 8  epoch 12  sequence. Average reward =  -8.871831841852421 . epsilon =  0.9789242003162011
# 8  epoch 13  sequence. Average reward =  -4.833324806605008 . epsilon =  0.9788263078961694
# 8  epoch 14  sequence. Average reward =  -6.1269341680054525 . epsilon =  0.9787284252653798
# 8  epoch 15  sequence. Average reward =  -6.468895953178348 . epsilon =  0.9786305524228534
# 8  epoch 16  sequence. Average reward =  -4.015922113875853 . epsilon =  0.9785326893676111
# 8  epoch 17  sequence. Average reward =  -5.089703659952633 . epsilon =  0.9784348360986743
# 8  epoch 18  sequence. Average reward =  -6.652364396953153 . epsilon =  0.9783369926150645
# 8  epoch 19  sequence. Average reward =  -5.708725051262335 . epsilon =  0.9782391589158029
# 8  epoch 20  sequence. Average reward =  -8.190922464418378 . epsilon =  0.9781413349999114
# 8  epoch 21  sequence. Average reward =  -5.66615456675469 . epsilon =  0.9780435208664114
# 8  epoch 22  sequence. Average reward =  -7.835245878548562 . epsilon =  0.9779457165143248
# 8  epoch 23  sequence. Average reward =  -6.575717550104083 . epsilon =  0.9778479219426734
# 8  epoch 24  sequence. Average reward =  -7.526538341647656 . epsilon =  0.9777501371504792
# 9  epoch 0  sequence. Average reward =  -7.390858532276703 . epsilon =  0.9776523621367642
# 9  epoch 1  sequence. Average reward =  -7.128464525308329 . epsilon =  0.9775545969005506
# 9  epoch 2  sequence. Average reward =  -6.992191170369252 . epsilon =  0.9774568414408605
# 9  epoch 3  sequence. Average reward =  -6.686612564506782 . epsilon =  0.9773590957567164
# 9  epoch 4  sequence. Average reward =  -7.809339646283416 . epsilon =  0.9772613598471408
# 9  epoch 5  sequence. Average reward =  -6.2977012118650135 . epsilon =  0.9771636337111561
# 9  epoch 6  sequence. Average reward =  -7.037179968450426 . epsilon =  0.977065917347785
# 9  epoch 7  sequence. Average reward =  -6.144639899098711 . epsilon =  0.9769682107560502
# 9  epoch 8  sequence. Average reward =  -7.481952500878231 . epsilon =  0.9768705139349746
# 9  epoch 9  sequence. Average reward =  -5.470837960913929 . epsilon =  0.9767728268835811
# 9  epoch 10  sequence. Average reward =  -4.028697095774658 . epsilon =  0.9766751496008927
# 9  epoch 11  sequence. Average reward =  -4.063226014432281 . epsilon =  0.9765774820859326
# 9  epoch 12  sequence. Average reward =  -6.316988472463119 . epsilon =  0.9764798243377241
# 9  epoch 13  sequence. Average reward =  -8.258488974841555 . epsilon =  0.9763821763552903
# 9  epoch 14  sequence. Average reward =  -4.947177687222025 . epsilon =  0.9762845381376548
# 9  epoch 15  sequence. Average reward =  -4.89020937594643 . epsilon =  0.976186909683841
# 9  epoch 16  sequence. Average reward =  -9.019598644786642 . epsilon =  0.9760892909928727
# 9  epoch 17  sequence. Average reward =  -5.6118397673947715 . epsilon =  0.9759916820637734
# 9  epoch 18  sequence. Average reward =  -7.530766685796137 . epsilon =  0.975894082895567
# 9  epoch 19  sequence. Average reward =  -6.4245075757206775 . epsilon =  0.9757964934872775
# 9  epoch 20  sequence. Average reward =  -7.2930087467479146 . epsilon =  0.9756989138379287
# 9  epoch 21  sequence. Average reward =  -4.49589224419964 . epsilon =  0.975601343946545
# 9  epoch 22  sequence. Average reward =  -5.6263085294122215 . epsilon =  0.9755037838121503
# 9  epoch 23  sequence. Average reward =  -7.106065862047444 . epsilon =  0.9754062334337691
# 9  epoch 24  sequence. Average reward =  -6.631745715802771 . epsilon =  0.9753086928104258
# 10  epoch 0  sequence. Average reward =  -6.146751840112235 . epsilon =  0.9752111619411448
# 10  epoch 1  sequence. Average reward =  -7.42495858932788 . epsilon =  0.9751136408249507
# 10  epoch 2  sequence. Average reward =  -6.140801295654676 . epsilon =  0.9750161294608681
# 10  epoch 3  sequence. Average reward =  -4.893598058413037 . epsilon =  0.974918627847922
# 10  epoch 4  sequence. Average reward =  -8.941342715701936 . epsilon =  0.9748211359851373
# 10  epoch 5  sequence. Average reward =  -5.319196854866653 . epsilon =  0.9747236538715388
# 10  epoch 6  sequence. Average reward =  -4.468417148068254 . epsilon =  0.9746261815061517
# 10  epoch 7  sequence. Average reward =  -4.47879776045536 . epsilon =  0.9745287188880011
# 10  epoch 8  sequence. Average reward =  -7.79849040274831 . epsilon =  0.9744312660161123
# 10  epoch 9  sequence. Average reward =  -4.511598484761722 . epsilon =  0.9743338228895106
# 10  epoch 10  sequence. Average reward =  -8.021318502172868 . epsilon =  0.9742363895072217
# 10  epoch 11  sequence. Average reward =  -4.224129142596896 . epsilon =  0.974138965868271
# 10  epoch 12  sequence. Average reward =  -4.848012241128766 . epsilon =  0.9740415519716842
# 10  epoch 13  sequence. Average reward =  -5.561089603622841 . epsilon =  0.973944147816487
# 10  epoch 14  sequence. Average reward =  -8.625789956002663 . epsilon =  0.9738467534017053
# 10  epoch 15  sequence. Average reward =  -6.478562397652781 . epsilon =  0.9737493687263652
# 10  epoch 16  sequence. Average reward =  -6.849205059925715 . epsilon =  0.9736519937894925
# 10  epoch 17  sequence. Average reward =  -6.49214274208597 . epsilon =  0.9735546285901135
# 10  epoch 18  sequence. Average reward =  -7.012663535114972 . epsilon =  0.9734572731272545
# 10  epoch 19  sequence. Average reward =  -5.493597172398449 . epsilon =  0.9733599273999418
# 10  epoch 20  sequence. Average reward =  -6.213861334056445 . epsilon =  0.9732625914072018
# 10  epoch 21  sequence. Average reward =  -5.163735474486649 . epsilon =  0.9731652651480611
# 10  epoch 22  sequence. Average reward =  -4.026938578099047 . epsilon =  0.9730679486215463
# 10  epoch 23  sequence. Average reward =  -6.584628081298351 . epsilon =  0.9729706418266841
# 10  epoch 24  sequence. Average reward =  -4.893255050798263 . epsilon =  0.9728733447625014
# 11  epoch 0  sequence. Average reward =  -5.7484922438108095 . epsilon =  0.9727760574280252
# 11  epoch 1  sequence. Average reward =  -6.099451176326136 . epsilon =  0.9726787798222825
# 11  epoch 2  sequence. Average reward =  -6.638801053441685 . epsilon =  0.9725815119443002
# 11  epoch 3  sequence. Average reward =  -4.753050514866604 . epsilon =  0.9724842537931058
# 11  epoch 4  sequence. Average reward =  -8.633378246959703 . epsilon =  0.9723870053677265
# 11  epoch 5  sequence. Average reward =  -4.840040261675956 . epsilon =  0.9722897666671897
# 11  epoch 6  sequence. Average reward =  -8.329204361098032 . epsilon =  0.9721925376905229
# 11  epoch 7  sequence. Average reward =  -5.617936491897564 . epsilon =  0.9720953184367539
# 11  epoch 8  sequence. Average reward =  -8.099677256268057 . epsilon =  0.9719981089049102
# 11  epoch 9  sequence. Average reward =  -4.894668555894628 . epsilon =  0.9719009090940197
# 11  epoch 10  sequence. Average reward =  -5.6372824744984555 . epsilon =  0.9718037190031104
# 11  epoch 11  sequence. Average reward =  -5.305272072079285 . epsilon =  0.97170653863121
# 11  epoch 12  sequence. Average reward =  -7.605829303073748 . epsilon =  0.9716093679773469
# 11  epoch 13  sequence. Average reward =  -4.487786750257952 . epsilon =  0.9715122070405492
# 11  epoch 14  sequence. Average reward =  -6.394320346522768 . epsilon =  0.9714150558198451
# 11  epoch 15  sequence. Average reward =  -3.9564484805052134 . epsilon =  0.9713179143142632
# 11  epoch 16  sequence. Average reward =  -4.867866315402203 . epsilon =  0.9712207825228317
# 11  epoch 17  sequence. Average reward =  -8.063429042073228 . epsilon =  0.9711236604445794
# 11  epoch 18  sequence. Average reward =  -5.655401509742047 . epsilon =  0.971026548078535
# 11  epoch 19  sequence. Average reward =  -5.770873424557383 . epsilon =  0.9709294454237271
# 11  epoch 20  sequence. Average reward =  -4.889170478842632 . epsilon =  0.9708323524791846
# 11  epoch 21  sequence. Average reward =  -6.726780311966873 . epsilon =  0.9707352692439367
# 11  epoch 22  sequence. Average reward =  -6.348775271947776 . epsilon =  0.9706381957170124
# 11  epoch 23  sequence. Average reward =  -4.402913896011277 . epsilon =  0.9705411318974407
# 11  epoch 24  sequence. Average reward =  -5.309624060342633 . epsilon =  0.970444077784251
# 12  epoch 0  sequence. Average reward =  -4.064328304748662 . epsilon =  0.9703470333764725
# 12  epoch 1  sequence. Average reward =  -8.495452185138713 . epsilon =  0.9702499986731349
# 12  epoch 2  sequence. Average reward =  -7.042132110597963 . epsilon =  0.9701529736732676
# 12  epoch 3  sequence. Average reward =  -6.075665428248523 . epsilon =  0.9700559583759003
# 12  epoch 4  sequence. Average reward =  -9.241640918595813 . epsilon =  0.9699589527800627
# 12  epoch 5  sequence. Average reward =  -4.456470064143542 . epsilon =  0.9698619568847847
# 12  epoch 6  sequence. Average reward =  -5.9790051298471365 . epsilon =  0.9697649706890963
# 12  epoch 7  sequence. Average reward =  -4.120260518553988 . epsilon =  0.9696679941920274
# 12  epoch 8  sequence. Average reward =  -4.5783349127122746 . epsilon =  0.9695710273926083
# 12  epoch 9  sequence. Average reward =  -4.456229533282193 . epsilon =  0.969474070289869
# 12  epoch 10  sequence. Average reward =  -7.330264641324944 . epsilon =  0.9693771228828401
# 12  epoch 11  sequence. Average reward =  -4.59590131707573 . epsilon =  0.9692801851705518
# 12  epoch 12  sequence. Average reward =  -4.684381843698422 . epsilon =  0.9691832571520348
# 12  epoch 13  sequence. Average reward =  -7.79756054153491 . epsilon =  0.9690863388263196
# 12  epoch 14  sequence. Average reward =  -5.731431232647409 . epsilon =  0.9689894301924369
# 12  epoch 15  sequence. Average reward =  -6.963459398253712 . epsilon =  0.9688925312494177
# 12  epoch 16  sequence. Average reward =  -4.805003530021403 . epsilon =  0.9687956419962928
# 12  epoch 17  sequence. Average reward =  -6.380964308836746 . epsilon =  0.9686987624320932
# 12  epoch 18  sequence. Average reward =  -4.42365297973546 . epsilon =  0.9686018925558499
# 12  epoch 19  sequence. Average reward =  -4.426525354111252 . epsilon =  0.9685050323665944
# 12  epoch 20  sequence. Average reward =  -5.6374104466706365 . epsilon =  0.9684081818633578
# 12  epoch 21  sequence. Average reward =  -8.591188252616186 . epsilon =  0.9683113410451715
# 12  epoch 22  sequence. Average reward =  -5.9294542920862625 . epsilon =  0.968214509911067
# 12  epoch 23  sequence. Average reward =  -8.62533637941603 . epsilon =  0.9681176884600758
# 12  epoch 24  sequence. Average reward =  -6.765453701322805 . epsilon =  0.9680208766912298
# 13  epoch 0  sequence. Average reward =  -8.280394556755319 . epsilon =  0.9679240746035607
# 13  epoch 1  sequence. Average reward =  -6.987975622201071 . epsilon =  0.9678272821961004
# 13  epoch 2  sequence. Average reward =  -5.2069214347476676 . epsilon =  0.9677304994678808
# 13  epoch 3  sequence. Average reward =  -4.609345911857203 . epsilon =  0.967633726417934
# 13  epoch 4  sequence. Average reward =  -4.06357338180363 . epsilon =  0.9675369630452922
# 13  epoch 5  sequence. Average reward =  -5.867809996841359 . epsilon =  0.9674402093489878
# 13  epoch 6  sequence. Average reward =  -6.765565229343064 . epsilon =  0.9673434653280529
# 13  epoch 7  sequence. Average reward =  -4.067771693205443 . epsilon =  0.9672467309815201
# 13  epoch 8  sequence. Average reward =  -6.266777534065155 . epsilon =  0.967150006308422
# 13  epoch 9  sequence. Average reward =  -7.996199649259039 . epsilon =  0.9670532913077912
# 13  epoch 10  sequence. Average reward =  -7.767490140074221 . epsilon =  0.9669565859786604
# 13  epoch 11  sequence. Average reward =  -4.269951690228361 . epsilon =  0.9668598903200626
# 13  epoch 12  sequence. Average reward =  -4.662022333142819 . epsilon =  0.9667632043310306
# 13  epoch 13  sequence. Average reward =  -6.575798304750127 . epsilon =  0.9666665280105975
# 13  epoch 14  sequence. Average reward =  -7.960362229714224 . epsilon =  0.9665698613577964
# 13  epoch 15  sequence. Average reward =  -7.802024506335167 . epsilon =  0.9664732043716606
# 13  epoch 16  sequence. Average reward =  -6.950561662501423 . epsilon =  0.9663765570512235
# 13  epoch 17  sequence. Average reward =  -5.9404010164472565 . epsilon =  0.9662799193955184
# 13  epoch 18  sequence. Average reward =  -5.215648131857277 . epsilon =  0.9661832914035788
# 13  epoch 19  sequence. Average reward =  -6.104699532055902 . epsilon =  0.9660866730744385
# 13  epoch 20  sequence. Average reward =  -7.906768545946527 . epsilon =  0.9659900644071311
# 13  epoch 21  sequence. Average reward =  -7.148224423839984 . epsilon =  0.9658934654006904
# 13  epoch 22  sequence. Average reward =  -4.820931258121326 . epsilon =  0.9657968760541503
# 13  epoch 23  sequence. Average reward =  -6.024475798623646 . epsilon =  0.9657002963665449
# 13  epoch 24  sequence. Average reward =  -4.876696148939795 . epsilon =  0.9656037263369083
# 14  epoch 0  sequence. Average reward =  -8.212262517032444 . epsilon =  0.9655071659642745
# 14  epoch 1  sequence. Average reward =  -7.666221156932854 . epsilon =  0.9654106152476781
# 14  epoch 2  sequence. Average reward =  -5.006947725561177 . epsilon =  0.9653140741861533
# 14  epoch 3  sequence. Average reward =  -7.671602277320191 . epsilon =  0.9652175427787347
# 14  epoch 4  sequence. Average reward =  -8.07580095520655 . epsilon =  0.9651210210244568
# 14  epoch 5  sequence. Average reward =  -5.342322800332339 . epsilon =  0.9650245089223544
# 14  epoch 6  sequence. Average reward =  -4.793744948604419 . epsilon =  0.9649280064714622
# 14  epoch 7  sequence. Average reward =  -6.574590025688564 . epsilon =  0.964831513670815
# 14  epoch 8  sequence. Average reward =  -6.6588353548914885 . epsilon =  0.9647350305194479
# 14  epoch 9  sequence. Average reward =  -6.07855183203943 . epsilon =  0.9646385570163959
# 14  epoch 10  sequence. Average reward =  -6.853448855840438 . epsilon =  0.9645420931606943
# 14  epoch 11  sequence. Average reward =  -4.3578066252915315 . epsilon =  0.9644456389513782
# 14  epoch 12  sequence. Average reward =  -4.843941868543971 . epsilon =  0.9643491943874831
# 14  epoch 13  sequence. Average reward =  -4.62199043479287 . epsilon =  0.9642527594680443
# 14  epoch 14  sequence. Average reward =  -4.415582108683431 . epsilon =  0.9641563341920976
# 14  epoch 15  sequence. Average reward =  -5.912166731029201 . epsilon =  0.9640599185586783
# 14  epoch 16  sequence. Average reward =  -4.517051354914463 . epsilon =  0.9639635125668224
# 14  epoch 17  sequence. Average reward =  -5.65628333698744 . epsilon =  0.9638671162155658
# 14  epoch 18  sequence. Average reward =  -5.674264511648188 . epsilon =  0.9637707295039442
# 14  epoch 19  sequence. Average reward =  -7.997601965430466 . epsilon =  0.9636743524309938
# 14  epoch 20  sequence. Average reward =  -6.66827661884273 . epsilon =  0.9635779849957506
# 14  epoch 21  sequence. Average reward =  -6.113197911814416 . epsilon =  0.9634816271972511
# 14  epoch 22  sequence. Average reward =  -6.141565965436219 . epsilon =  0.9633852790345313
# 14  epoch 23  sequence. Average reward =  -8.377356185611935 . epsilon =  0.9632889405066278
# 14  epoch 24  sequence. Average reward =  -4.782976596267556 . epsilon =  0.9631926116125772
# 15  epoch 0  sequence. Average reward =  -7.053686677356266 . epsilon =  0.9630962923514159
# 15  epoch 1  sequence. Average reward =  -5.102507102352963 . epsilon =  0.9629999827221808
# 15  epoch 2  sequence. Average reward =  -4.100936392367054 . epsilon =  0.9629036827239086
# 15  epoch 3  sequence. Average reward =  -4.5592316209755275 . epsilon =  0.9628073923556362
# 15  epoch 4  sequence. Average reward =  -7.588798396954916 . epsilon =  0.9627111116164007
# 15  epoch 5  sequence. Average reward =  -8.351741637078081 . epsilon =  0.962614840505239
# 15  epoch 6  sequence. Average reward =  -5.151123764065559 . epsilon =  0.9625185790211885
# 15  epoch 7  sequence. Average reward =  -4.302153903957071 . epsilon =  0.9624223271632865
# 15  epoch 8  sequence. Average reward =  -4.238562383778583 . epsilon =  0.9623260849305701
# 15  epoch 9  sequence. Average reward =  -6.88389145211927 . epsilon =  0.9622298523220771
# 15  epoch 10  sequence. Average reward =  -4.982390942084124 . epsilon =  0.962133629336845
# 15  epoch 11  sequence. Average reward =  -8.353534402093652 . epsilon =  0.9620374159739113
# 15  epoch 12  sequence. Average reward =  -6.22924580467649 . epsilon =  0.961941212232314
# 15  epoch 13  sequence. Average reward =  -6.076307759316732 . epsilon =  0.9618450181110908
# 15  epoch 14  sequence. Average reward =  -7.069712013420094 . epsilon =  0.9617488336092797
# 15  epoch 15  sequence. Average reward =  -7.29919830745765 . epsilon =  0.9616526587259188
# 15  epoch 16  sequence. Average reward =  -7.2412310725530435 . epsilon =  0.9615564934600462
# 15  epoch 17  sequence. Average reward =  -7.439961454043637 . epsilon =  0.9614603378107003
# 15  epoch 18  sequence. Average reward =  -5.9777182194640766 . epsilon =  0.9613641917769192
# 15  epoch 19  sequence. Average reward =  -4.793414517307263 . epsilon =  0.9612680553577415
# 15  epoch 20  sequence. Average reward =  -4.846473113368085 . epsilon =  0.9611719285522058
# 15  epoch 21  sequence. Average reward =  -6.948923962585973 . epsilon =  0.9610758113593506
# 15  epoch 22  sequence. Average reward =  -6.805574000607863 . epsilon =  0.9609797037782147
# 15  epoch 23  sequence. Average reward =  -8.814316492800973 . epsilon =  0.9608836058078369
# 15  epoch 24  sequence. Average reward =  -8.26882578989666 . epsilon =  0.9607875174472562
# 16  epoch 0  sequence. Average reward =  -6.393711171654603 . epsilon =  0.9606914386955115
# 16  epoch 1  sequence. Average reward =  -5.6459371407408225 . epsilon =  0.960595369551642
# 16  epoch 2  sequence. Average reward =  -4.58422686211466 . epsilon =  0.9604993100146869
# 16  epoch 3  sequence. Average reward =  -6.696922530111868 . epsilon =  0.9604032600836855
# 16  epoch 4  sequence. Average reward =  -5.602758754673106 . epsilon =  0.9603072197576771
# 16  epoch 5  sequence. Average reward =  -5.624417594945027 . epsilon =  0.9602111890357014
# 16  epoch 6  sequence. Average reward =  -5.94634103975236 . epsilon =  0.9601151679167977
# 16  epoch 7  sequence. Average reward =  -6.187305424322717 . epsilon =  0.9600191564000061
# 16  epoch 8  sequence. Average reward =  -4.821830361472705 . epsilon =  0.9599231544843662
# 16  epoch 9  sequence. Average reward =  -6.073888385643562 . epsilon =  0.9598271621689177
# 16  epoch 10  sequence. Average reward =  -5.395885853300733 . epsilon =  0.9597311794527008
# 16  epoch 11  sequence. Average reward =  -4.878140809520692 . epsilon =  0.9596352063347555
# 16  epoch 12  sequence. Average reward =  -7.752100124072663 . epsilon =  0.9595392428141221
# 16  epoch 13  sequence. Average reward =  -8.24807759560788 . epsilon =  0.9594432888898407
# 16  epoch 14  sequence. Average reward =  -7.240301738152669 . epsilon =  0.9593473445609517
# 16  epoch 15  sequence. Average reward =  -6.012963602932136 . epsilon =  0.9592514098264956
# 16  epoch 16  sequence. Average reward =  -8.449663799982535 . epsilon =  0.9591554846855129
# 16  epoch 17  sequence. Average reward =  -7.878903997117307 . epsilon =  0.9590595691370444
# 16  epoch 18  sequence. Average reward =  -4.891936036543948 . epsilon =  0.9589636631801307
# 16  epoch 19  sequence. Average reward =  -6.664291468183176 . epsilon =  0.9588677668138127
# 16  epoch 20  sequence. Average reward =  -4.829276649844668 . epsilon =  0.9587718800371313
# 16  epoch 21  sequence. Average reward =  -6.903344191655553 . epsilon =  0.9586760028491276
# 16  epoch 22  sequence. Average reward =  -5.620446568822161 . epsilon =  0.9585801352488427
# 16  epoch 23  sequence. Average reward =  -4.820492404325877 . epsilon =  0.9584842772353178
# 16  epoch 24  sequence. Average reward =  -6.788619842924668 . epsilon =  0.9583884288075943
# 17  epoch 0  sequence. Average reward =  -5.750727473863459 . epsilon =  0.9582925899647136
# 17  epoch 1  sequence. Average reward =  -7.302064216153747 . epsilon =  0.9581967607057171
# 17  epoch 2  sequence. Average reward =  -6.996745561770967 . epsilon =  0.9581009410296466
# 17  epoch 3  sequence. Average reward =  -4.6038507141787886 . epsilon =  0.9580051309355436
# 17  epoch 4  sequence. Average reward =  -6.453840029651994 . epsilon =  0.9579093304224501
# 17  epoch 5  sequence. Average reward =  -5.260039116128328 . epsilon =  0.9578135394894078
# 17  epoch 6  sequence. Average reward =  -6.08172275381943 . epsilon =  0.9577177581354589
# 17  epoch 7  sequence. Average reward =  -4.254778089105569 . epsilon =  0.9576219863596453
# 17  epoch 8  sequence. Average reward =  -8.40638115181541 . epsilon =  0.9575262241610094
# 17  epoch 9  sequence. Average reward =  -4.694558546016563 . epsilon =  0.9574304715385933
# 17  epoch 10  sequence. Average reward =  -4.429244803808754 . epsilon =  0.9573347284914394
# 17  epoch 11  sequence. Average reward =  -4.073514233288228 . epsilon =  0.9572389950185903
# 17  epoch 12  sequence. Average reward =  -8.821686301924096 . epsilon =  0.9571432711190885
# 17  epoch 13  sequence. Average reward =  -6.462661967211478 . epsilon =  0.9570475567919766
# 17  epoch 14  sequence. Average reward =  -8.462948372303758 . epsilon =  0.9569518520362974
# 17  epoch 15  sequence. Average reward =  -4.845215548825329 . epsilon =  0.9568561568510938
# 17  epoch 16  sequence. Average reward =  -7.282265059039383 . epsilon =  0.9567604712354087
# 17  epoch 17  sequence. Average reward =  -5.282767409260169 . epsilon =  0.9566647951882852
# 17  epoch 18  sequence. Average reward =  -7.888802555827457 . epsilon =  0.9565691287087663
# 17  epoch 19  sequence. Average reward =  -4.878000101138085 . epsilon =  0.9564734717958955
# 17  epoch 20  sequence. Average reward =  -6.775770039576949 . epsilon =  0.9563778244487159
# 17  epoch 21  sequence. Average reward =  -6.41294542222594 . epsilon =  0.9562821866662711
# 17  epoch 22  sequence. Average reward =  -7.781515857012782 . epsilon =  0.9561865584476045
# 17  epoch 23  sequence. Average reward =  -4.84218195105038 . epsilon =  0.9560909397917597
# 17  epoch 24  sequence. Average reward =  -7.770251131452207 . epsilon =  0.9559953306977805
# 18  epoch 0  sequence. Average reward =  -5.090519551206622 . epsilon =  0.9558997311647107
# 18  epoch 1  sequence. Average reward =  -4.464934982240373 . epsilon =  0.9558041411915943
# 18  epoch 2  sequence. Average reward =  -8.024624719413602 . epsilon =  0.9557085607774751
# 18  epoch 3  sequence. Average reward =  -3.915093637175689 . epsilon =  0.9556129899213974
# 18  epoch 4  sequence. Average reward =  -4.334411870752906 . epsilon =  0.9555174286224053
# 18  epoch 5  sequence. Average reward =  -6.625765659360806 . epsilon =  0.955421876879543
# 18  epoch 6  sequence. Average reward =  -5.260596049973294 . epsilon =  0.9553263346918551
# 18  epoch 7  sequence. Average reward =  -4.553348286795113 . epsilon =  0.955230802058386
# 18  epoch 8  sequence. Average reward =  -4.514205244678845 . epsilon =  0.9551352789781802
# 18  epoch 9  sequence. Average reward =  -6.897406343327691 . epsilon =  0.9550397654502824
# 18  epoch 10  sequence. Average reward =  -4.008268959965593 . epsilon =  0.9549442614737373
# 18  epoch 11  sequence. Average reward =  -4.984066414485094 . epsilon =  0.95484876704759
# 18  epoch 12  sequence. Average reward =  -4.861741206561748 . epsilon =  0.9547532821708853
# 18  epoch 13  sequence. Average reward =  -4.79892027500798 . epsilon =  0.9546578068426682
# 18  epoch 14  sequence. Average reward =  -6.665924320658465 . epsilon =  0.9545623410619839
# 18  epoch 15  sequence. Average reward =  -6.992813167197005 . epsilon =  0.9544668848278777
# 18  epoch 16  sequence. Average reward =  -6.178143744566536 . epsilon =  0.9543714381393948
# 18  epoch 17  sequence. Average reward =  -6.616103011479568 . epsilon =  0.954276000995581
# 18  epoch 18  sequence. Average reward =  -7.579815931701663 . epsilon =  0.9541805733954815
# 18  epoch 19  sequence. Average reward =  -5.777489169268684 . epsilon =  0.9540851553381419
# 18  epoch 20  sequence. Average reward =  -4.433110819310194 . epsilon =  0.9539897468226081
# 18  epoch 21  sequence. Average reward =  -7.877726308513869 . epsilon =  0.9538943478479258
# 18  epoch 22  sequence. Average reward =  -4.741947349018771 . epsilon =  0.953798958413141
# 18  epoch 23  sequence. Average reward =  -5.824568395127674 . epsilon =  0.9537035785172997
# 18  epoch 24  sequence. Average reward =  -4.488756638690631 . epsilon =  0.953608208159448
# 19  epoch 0  sequence. Average reward =  -7.522592897095237 . epsilon =  0.9535128473386321
# 19  epoch 1  sequence. Average reward =  -7.111928386634672 . epsilon =  0.9534174960538983
# 19  epoch 2  sequence. Average reward =  -4.250805084622235 . epsilon =  0.9533221543042929
# 19  epoch 3  sequence. Average reward =  -6.596327101002801 . epsilon =  0.9532268220888624
# 19  epoch 4  sequence. Average reward =  -5.2612603479524145 . epsilon =  0.9531314994066535
# 19  epoch 5  sequence. Average reward =  -5.778177506558538 . epsilon =  0.9530361862567129
# 19  epoch 6  sequence. Average reward =  -4.871523151095662 . epsilon =  0.9529408826380873
# 19  epoch 7  sequence. Average reward =  -6.547458662453913 . epsilon =  0.9528455885498235
# 19  epoch 8  sequence. Average reward =  -5.8819916873930485 . epsilon =  0.9527503039909685
# 19  epoch 9  sequence. Average reward =  -8.487238370668983 . epsilon =  0.9526550289605694
# 19  epoch 10  sequence. Average reward =  -4.778807378285941 . epsilon =  0.9525597634576733
# 19  epoch 11  sequence. Average reward =  -4.39789421011204 . epsilon =  0.9524645074813276
# 19  epoch 12  sequence. Average reward =  -6.080417245377042 . epsilon =  0.9523692610305795
# 19  epoch 13  sequence. Average reward =  -4.785209211104906 . epsilon =  0.9522740241044765
# 19  epoch 14  sequence. Average reward =  -7.8405922032963495 . epsilon =  0.9521787967020661
# 19  epoch 15  sequence. Average reward =  -5.692782191144219 . epsilon =  0.9520835788223959
# 19  epoch 16  sequence. Average reward =  -4.58083875292151 . epsilon =  0.9519883704645137
# 19  epoch 17  sequence. Average reward =  -4.539168826913893 . epsilon =  0.9518931716274672
# 19  epoch 18  sequence. Average reward =  -5.315218915272335 . epsilon =  0.9517979823103044
# 19  epoch 19  sequence. Average reward =  -7.1101683208360695 . epsilon =  0.9517028025120734
# 19  epoch 20  sequence. Average reward =  -7.859867702735766 . epsilon =  0.9516076322318222
# 19  epoch 21  sequence. Average reward =  -6.097197696264229 . epsilon =  0.9515124714685991
# 19  epoch 22  sequence. Average reward =  -8.733858599120763 . epsilon =  0.9514173202214522
# 19  epoch 23  sequence. Average reward =  -4.556919302182483 . epsilon =  0.95132217848943
# 19  epoch 24  sequence. Average reward =  -5.207778640926929 . epsilon =  0.9512270462715811
# 20  epoch 0  sequence. Average reward =  -5.415028869908952 . epsilon =  0.9511319235669539
# 20  epoch 1  sequence. Average reward =  -7.908096587590816 . epsilon =  0.9510368103745972
# 20  epoch 2  sequence. Average reward =  -4.304645608741621 . epsilon =  0.9509417066935597
# 20  epoch 3  sequence. Average reward =  -5.0593029934463 . epsilon =  0.9508466125228904
# 20  epoch 4  sequence. Average reward =  -7.585939909057773 . epsilon =  0.9507515278616381
# 20  epoch 5  sequence. Average reward =  -8.564418452146757 . epsilon =  0.9506564527088519
# 20  epoch 6  sequence. Average reward =  -7.188283693740696 . epsilon =  0.9505613870635811
# 20  epoch 7  sequence. Average reward =  -6.0102917222440455 . epsilon =  0.9504663309248748
# 20  epoch 8  sequence. Average reward =  -4.977884797732632 . epsilon =  0.9503712842917823
# 20  epoch 9  sequence. Average reward =  -7.3804297499375835 . epsilon =  0.9502762471633531
# 20  epoch 10  sequence. Average reward =  -3.9991447446971287 . epsilon =  0.9501812195386368
# 20  epoch 11  sequence. Average reward =  -4.4602132604668565 . epsilon =  0.9500862014166829
# 20  epoch 12  sequence. Average reward =  -4.8454918093060755 . epsilon =  0.9499911927965412
# 20  epoch 13  sequence. Average reward =  -6.734781638359381 . epsilon =  0.9498961936772615
# 20  epoch 14  sequence. Average reward =  -4.829304372157849 . epsilon =  0.9498012040578938
# 20  epoch 15  sequence. Average reward =  -6.133003873664004 . epsilon =  0.949706223937488
# 20  epoch 16  sequence. Average reward =  -3.966036329564494 . epsilon =  0.9496112533150943
# 20  epoch 17  sequence. Average reward =  -5.1182176780403 . epsilon =  0.9495162921897629
# 20  epoch 18  sequence. Average reward =  -7.333312045946931 . epsilon =  0.9494213405605438
# 20  epoch 19  sequence. Average reward =  -4.016992471652571 . epsilon =  0.9493263984264878
# 20  epoch 20  sequence. Average reward =  -8.870713927833487 . epsilon =  0.9492314657866452
# ...
# 33  epoch 4  sequence. Average reward =  -8.001783825490593 . epsilon =  0.9203473275161489
# 33  epoch 5  sequence. Average reward =  -4.43612186816257 . epsilon =  0.9202552927833972
# 33  epoch 6  sequence. Average reward =  -6.627595232672373 . epsilon =  0.9201632672541189
# 33  epoch 7  sequence. Average reward =  -4.901273687005176 . epsilon =  0.9200712509273935
# 33  epoch 8  sequence. Average reward =  -4.3938019594574556 . epsilon =  0.9199792438023008
# 33  epoch 9  sequence. Average reward =  -6.798512957388812 . epsilon =  0.9198872458779206
# 33  epoch 10  sequence. Average reward =  -7.032324921950614 . epsilon =  0.9197952571533328
# 33  epoch 11  sequence. Average reward =  -3.967574150030793 . epsilon =  0.9197032776276175
# 33  epoch 12  sequence. Average reward =  -3.9609270149607845 . epsilon =  0.9196113072998547
# 33  epoch 13  sequence. Average reward =  -3.994887173219768 . epsilon =  0.9195193461691248
# 33  epoch 14  sequence. Average reward =  -5.300908836520376 . epsilon =  0.9194273942345079
# 33  epoch 15  sequence. Average reward =  -9.296271356104329 . epsilon =  0.9193354514950844
# 33  epoch 16  sequence. Average reward =  -6.110425814490374 . epsilon =  0.919243517949935
# 33  epoch 17  sequence. Average reward =  -5.567276299878013 . epsilon =  0.91915159359814
# 33  epoch 18  sequence. Average reward =  -7.290716296254923 . epsilon =  0.9190596784387802
# 33  epoch 19  sequence. Average reward =  -8.107906901150665 . epsilon =  0.9189677724709363
# 33  epoch 20  sequence. Average reward =  -5.581791198792723 . epsilon =  0.9188758756936892
# 33  epoch 21  sequence. Average reward =  -4.119776845463917 . epsilon =  0.9187839881061198
# 33  epoch 22  sequence. Average reward =  -5.158696132379119 . epsilon =  0.9186921097073092
# 33  epoch 23  sequence. Average reward =  -4.472072206626436 . epsilon =  0.9186002404963385
# 33  epoch 24  sequence. Average reward =  -4.25662204865431 . epsilon =  0.9185083804722889
# 34  epoch 0  sequence. Average reward =  -6.738922898754972 . epsilon =  0.9184165296342417
# 34  epoch 1  sequence. Average reward =  -7.098364016513047 . epsilon =  0.9183246879812783
# 34  epoch 2  sequence. Average reward =  -7.2758787380593475 . epsilon =  0.9182328555124802
# 34  epoch 3  sequence. Average reward =  -6.2764188151550355 . epsilon =  0.918141032226929
# 34  epoch 4  sequence. Average reward =  -4.52625782220942 . epsilon =  0.9180492181237063
# 34  epoch 5  sequence. Average reward =  -5.744472096569122 . epsilon =  0.917957413201894
# 34  epoch 6  sequence. Average reward =  -8.286383765112541 . epsilon =  0.9178656174605737
# 34  epoch 7  sequence. Average reward =  -6.891864194865514 . epsilon =  0.9177738308988277
# 34  epoch 8  sequence. Average reward =  -8.607214514870899 . epsilon =  0.9176820535157378
# 34  epoch 9  sequence. Average reward =  -4.942945079891727 . epsilon =  0.9175902853103862
# 34  epoch 10  sequence. Average reward =  -5.281153229549615 . epsilon =  0.9174985262818552
# 34  epoch 11  sequence. Average reward =  -8.53164838223621 . epsilon =  0.9174067764292271
# 34  epoch 12  sequence. Average reward =  -8.137607601329627 . epsilon =  0.9173150357515841
# 34  epoch 13  sequence. Average reward =  -4.777335816049822 . epsilon =  0.917223304248009
# 34  epoch 14  sequence. Average reward =  -3.484722510793881 . epsilon =  0.9171315819175843
# 34  epoch 15  sequence. Average reward =  -7.592770731312879 . epsilon =  0.9170398687593925
# 34  epoch 16  sequence. Average reward =  -3.9033577634234593 . epsilon =  0.9169481647725165
# 34  epoch 17  sequence. Average reward =  -6.278249908697249 . epsilon =  0.9168564699560393
# 34  epoch 18  sequence. Average reward =  -5.738778838825548 . epsilon =  0.9167647843090437
# 34  epoch 19  sequence. Average reward =  -6.152319188296389 . epsilon =  0.9166731078306128
# 34  epoch 20  sequence. Average reward =  -8.38866376031949 . epsilon =  0.9165814405198298
# 34  epoch 21  sequence. Average reward =  -6.10241759842298 . epsilon =  0.9164897823757778
# 34  epoch 22  sequence. Average reward =  -8.654205289224562 . epsilon =  0.9163981333975403
# 34  epoch 23  sequence. Average reward =  -7.832656514549348 . epsilon =  0.9163064935842006
# 34  epoch 24  sequence. Average reward =  -6.047047873719537 . epsilon =  0.9162148629348421
# 35  epoch 0  sequence. Average reward =  -5.903384059134956 . epsilon =  0.9161232414485486
# 35  epoch 1  sequence. Average reward =  -6.482425798179917 . epsilon =  0.9160316291244037
# 35  epoch 2  sequence. Average reward =  -6.6740258352692985 . epsilon =  0.9159400259614913
# 35  epoch 3  sequence. Average reward =  -4.075247282979195 . epsilon =  0.9158484319588951
# 35  epoch 4  sequence. Average reward =  -5.4543140224142155 . epsilon =  0.9157568471156993
# 35  epoch 5  sequence. Average reward =  -5.238824616789906 . epsilon =  0.9156652714309877
# 35  epoch 6  sequence. Average reward =  -4.435679507223871 . epsilon =  0.9155737049038447
# 35  epoch 7  sequence. Average reward =  -5.666110167499663 . epsilon =  0.9154821475333543
# 35  epoch 8  sequence. Average reward =  -8.868103385668377 . epsilon =  0.915390599318601
# 35  epoch 9  sequence. Average reward =  -7.28763492459264 . epsilon =  0.9152990602586691
# 35  epoch 10  sequence. Average reward =  -3.748291207559026 . epsilon =  0.9152075303526432
# 35  epoch 11  sequence. Average reward =  -7.436597929863145 . epsilon =  0.915116009599608
# 35  epoch 12  sequence. Average reward =  -4.5254614059596285 . epsilon =  0.915024497998648
# 35  epoch 13  sequence. Average reward =  -5.696921605684646 . epsilon =  0.9149329955488482
# 35  epoch 14  sequence. Average reward =  -4.07565932594962 . epsilon =  0.9148415022492934
# 35  epoch 15  sequence. Average reward =  -7.4887892437843595 . epsilon =  0.9147500180990684
# 35  epoch 16  sequence. Average reward =  -6.974309548829651 . epsilon =  0.9146585430972585
# 35  epoch 17  sequence. Average reward =  -8.348081925777981 . epsilon =  0.9145670772429487
# 35  epoch 18  sequence. Average reward =  -4.956711734485893 . epsilon =  0.9144756205352245
# 35  epoch 19  sequence. Average reward =  -8.128119403588018 . epsilon =  0.914384172973171
# 35  epoch 20  sequence. Average reward =  -7.527288123216595 . epsilon =  0.9142927345558737
# 35  epoch 21  sequence. Average reward =  -5.673605257864507 . epsilon =  0.914201305282418
# 35  epoch 22  sequence. Average reward =  -5.720923495252645 . epsilon =  0.9141098851518898
# 35  epoch 23  sequence. Average reward =  -4.953074086872445 . epsilon =  0.9140184741633747
# 35  epoch 24  sequence. Average reward =  -7.668784106869402 . epsilon =  0.9139270723159584
# 36  epoch 0  sequence. Average reward =  -5.26290659935886 . epsilon =  0.9138356796087268
# 36  epoch 1  sequence. Average reward =  -6.882593213507597 . epsilon =  0.9137442960407659
# 36  epoch 2  sequence. Average reward =  -7.701859290201 . epsilon =  0.9136529216111619
# 36  epoch 3  sequence. Average reward =  -8.767110063000459 . epsilon =  0.9135615563190007
# 36  epoch 4  sequence. Average reward =  -7.565968826131841 . epsilon =  0.9134702001633688
# 36  epoch 5  sequence. Average reward =  -8.475469724259609 . epsilon =  0.9133788531433524
# 36  epoch 6  sequence. Average reward =  -5.211504024410066 . epsilon =  0.9132875152580381
# 36  epoch 7  sequence. Average reward =  -5.105020548330928 . epsilon =  0.9131961865065122
# 36  epoch 8  sequence. Average reward =  -4.86444427342605 . epsilon =  0.9131048668878616
# 36  epoch 9  sequence. Average reward =  -4.0806224090254775 . epsilon =  0.9130135564011729
# 36  epoch 10  sequence. Average reward =  -8.213065739629839 . epsilon =  0.9129222550455328
# 36  epoch 11  sequence. Average reward =  -8.916099458242885 . epsilon =  0.9128309628200283
# 36  epoch 12  sequence. Average reward =  -7.152133337939369 . epsilon =  0.9127396797237463
# 36  epoch 13  sequence. Average reward =  -8.347451821114213 . epsilon =  0.9126484057557739
# 36  epoch 14  sequence. Average reward =  -6.24027030356567 . epsilon =  0.9125571409151984
# 36  epoch 15  sequence. Average reward =  -6.135875067892642 . epsilon =  0.9124658852011068
# 36  epoch 16  sequence. Average reward =  -6.852862877755201 . epsilon =  0.9123746386125867
# 36  epoch 17  sequence. Average reward =  -5.162105160609798 . epsilon =  0.9122834011487255
# 36  epoch 18  sequence. Average reward =  -5.65944757276138 . epsilon =  0.9121921728086106
# 36  epoch 19  sequence. Average reward =  -5.233433060098764 . epsilon =  0.9121009535913298
# 36  epoch 20  sequence. Average reward =  -7.707467798302003 . epsilon =  0.9120097434959706
# 36  epoch 21  sequence. Average reward =  -7.260757237128251 . epsilon =  0.9119185425216211
# 36  epoch 22  sequence. Average reward =  -7.007486093820313 . epsilon =  0.911827350667369
# 36  epoch 23  sequence. Average reward =  -7.325224019691788 . epsilon =  0.9117361679323023
# 36  epoch 24  sequence. Average reward =  -7.1569349818371615 . epsilon =  0.911644994315509
# 37  epoch 0  sequence. Average reward =  -7.428778484378922 . epsilon =  0.9115538298160775
# 37  epoch 1  sequence. Average reward =  -8.917815021586826 . epsilon =  0.9114626744330959
# 37  epoch 2  sequence. Average reward =  -5.165071554140846 . epsilon =  0.9113715281656526
# 37  epoch 3  sequence. Average reward =  -4.46032551376545 . epsilon =  0.9112803910128361
# 37  epoch 4  sequence. Average reward =  -4.42141577243451 . epsilon =  0.9111892629737348
# 37  epoch 5  sequence. Average reward =  -7.888651631390586 . epsilon =  0.9110981440474375
# 37  epoch 6  sequence. Average reward =  -4.473613591798421 . epsilon =  0.9110070342330328
# 37  epoch 7  sequence. Average reward =  -7.775524451915136 . epsilon =  0.9109159335296094
# 37  epoch 8  sequence. Average reward =  -6.948618862604908 . epsilon =  0.9108248419362565
# 37  epoch 9  sequence. Average reward =  -6.615880475452315 . epsilon =  0.9107337594520628
# 37  epoch 10  sequence. Average reward =  -7.438226023302679 . epsilon =  0.9106426860761176
# 37  epoch 11  sequence. Average reward =  -6.042792312666309 . epsilon =  0.91055162180751
# 37  epoch 12  sequence. Average reward =  -7.372673517277846 . epsilon =  0.9104605666453293
# 37  epoch 13  sequence. Average reward =  -4.9533436899909775 . epsilon =  0.9103695205886647
# 37  epoch 14  sequence. Average reward =  -6.739941059625295 . epsilon =  0.9102784836366059
# 37  epoch 15  sequence. Average reward =  -4.4890879702071915 . epsilon =  0.9101874557882422
# 37  epoch 16  sequence. Average reward =  -4.516841090425782 . epsilon =  0.9100964370426634
# 37  epoch 17  sequence. Average reward =  -6.880310397989767 . epsilon =  0.9100054273989592
# 37  epoch 18  sequence. Average reward =  -7.935372976493076 . epsilon =  0.9099144268562193
# 37  epoch 19  sequence. Average reward =  -5.594169665050093 . epsilon =  0.9098234354135336
# 37  epoch 20  sequence. Average reward =  -4.695141985361747 . epsilon =  0.9097324530699923
# 37  epoch 21  sequence. Average reward =  -4.780521701945175 . epsilon =  0.9096414798246854
# 37  epoch 22  sequence. Average reward =  -4.816702741181156 . epsilon =  0.9095505156767029
# 37  epoch 23  sequence. Average reward =  -8.261068006687927 . epsilon =  0.9094595606251352
# 37  epoch 24  sequence. Average reward =  -6.809913293644929 . epsilon =  0.9093686146690727
# 38  epoch 0  sequence. Average reward =  -6.349101326722123 . epsilon =  0.9092776778076058
# 38  epoch 1  sequence. Average reward =  -6.63513391020959 . epsilon =  0.9091867500398251
# 38  epoch 2  sequence. Average reward =  -4.818311917457945 . epsilon =  0.9090958313648211
# 38  epoch 3  sequence. Average reward =  -7.739897453373894 . epsilon =  0.9090049217816846
# 38  epoch 4  sequence. Average reward =  -8.199430077774114 . epsilon =  0.9089140212895064
# 38  epoch 5  sequence. Average reward =  -4.151261996035831 . epsilon =  0.9088231298873775
# 38  epoch 6  sequence. Average reward =  -6.857006869488148 . epsilon =  0.9087322475743888
# 38  epoch 7  sequence. Average reward =  -4.466658576378556 . epsilon =  0.9086413743496313
# 38  epoch 8  sequence. Average reward =  -4.7660717035607885 . epsilon =  0.9085505102121963
# 38  epoch 9  sequence. Average reward =  -6.088441335997083 . epsilon =  0.9084596551611751
# 38  epoch 10  sequence. Average reward =  -4.831611054217454 . epsilon =  0.908368809195659
# 38  epoch 11  sequence. Average reward =  -8.545682616149893 . epsilon =  0.9082779723147394
# 38  epoch 12  sequence. Average reward =  -8.11428091520096 . epsilon =  0.9081871445175079
# 38  epoch 13  sequence. Average reward =  -6.314098322236278 . epsilon =  0.9080963258030562
# 38  epoch 14  sequence. Average reward =  -5.048588625926853 . epsilon =  0.9080055161704759
# 38  epoch 15  sequence. Average reward =  -6.736874641231265 . epsilon =  0.9079147156188588
# 38  epoch 16  sequence. Average reward =  -8.21576953827371 . epsilon =  0.907823924147297
# 38  epoch 17  sequence. Average reward =  -6.776371337086238 . epsilon =  0.9077331417548823
# 38  epoch 18  sequence. Average reward =  -5.157446090377673 . epsilon =  0.9076423684407068
# 38  epoch 19  sequence. Average reward =  -4.371757575739862 . epsilon =  0.9075516042038627
# 38  epoch 20  sequence. Average reward =  -4.776411069801985 . epsilon =  0.9074608490434424
# 38  epoch 21  sequence. Average reward =  -5.415172010381633 . epsilon =  0.907370102958538
# 38  epoch 22  sequence. Average reward =  -7.4622664587109995 . epsilon =  0.9072793659482422
# 38  epoch 23  sequence. Average reward =  -5.70896381644525 . epsilon =  0.9071886380116474
# 38  epoch 24  sequence. Average reward =  -5.899088685513484 . epsilon =  0.9070979191478462
# 39  epoch 0  sequence. Average reward =  -4.579507918052403 . epsilon =  0.9070072093559315
# 39  epoch 1  sequence. Average reward =  -8.666573096494961 . epsilon =  0.906916508634996
# 39  epoch 2  sequence. Average reward =  -7.951628601696812 . epsilon =  0.9068258169841324
# 39  epoch 3  sequence. Average reward =  -5.455554016330673 . epsilon =  0.906735134402434
# 39  epoch 4  sequence. Average reward =  -4.356814909994107 . epsilon =  0.9066444608889938
# 39  epoch 5  sequence. Average reward =  -7.519907474294005 . epsilon =  0.9065537964429049
# 39  epoch 6  sequence. Average reward =  -8.39348883750282 . epsilon =  0.9064631410632606
# 39  epoch 7  sequence. Average reward =  -4.794413044068598 . epsilon =  0.9063724947491544
# 39  epoch 8  sequence. Average reward =  -8.458751785760873 . epsilon =  0.9062818574996795
# 39  epoch 9  sequence. Average reward =  -4.016294623024551 . epsilon =  0.9061912293139295
# 39  epoch 10  sequence. Average reward =  -7.581260007091174 . epsilon =  0.9061006101909981
# 39  epoch 11  sequence. Average reward =  -6.754787545630454 . epsilon =  0.906010000129979
# 39  epoch 12  sequence. Average reward =  -4.3277845314340215 . epsilon =  0.905919399129966
# 39  epoch 13  sequence. Average reward =  -5.749024842162889 . epsilon =  0.905828807190053
# 39  epoch 14  sequence. Average reward =  -7.350235477987259 . epsilon =  0.905738224309334
# 39  epoch 15  sequence. Average reward =  -7.7493551473545175 . epsilon =  0.9056476504869031
# 39  epoch 16  sequence. Average reward =  -6.857727895241414 . epsilon =  0.9055570857218544
# 39  epoch 17  sequence. Average reward =  -4.9026326341629085 . epsilon =  0.9054665300132823
# 39  epoch 18  sequence. Average reward =  -6.139708598953626 . epsilon =  0.9053759833602809
# 39  epoch 19  sequence. Average reward =  -4.86876562070917 . epsilon =  0.9052854457619449
# 39  epoch 20  sequence. Average reward =  -6.465248235119026 . epsilon =  0.9051949172173688
# 39  epoch 21  sequence. Average reward =  -7.60732538556166 . epsilon =  0.9051043977256471
# 39  epoch 22  sequence. Average reward =  -6.861393027701754 . epsilon =  0.9050138872858745
# 39  epoch 23  sequence. Average reward =  -4.510636638288878 . epsilon =  0.9049233858971459
# 39  epoch 24  sequence. Average reward =  -7.541595410697838 . epsilon =  0.9048328935585562
# '\ntraining takes super long, this is not efficient at all, how can we bypass this?\nHint: See cells in run pretrained model.\n\n'

# %%
# Save model weights

print('saving model')
model.save('pendulum_model_juno_' + str(training_iterations) + '.h5')
print('model saved')
# Out:
# saving model
# model saved

# %%
# Evaluate performance on 10 test runs with 100 steps each
trarray = []
rounds = 100
for i in range(10):
    trarray.append(play_game(rounds))
    print(i, ' sequence. Average test reward = ', np.average(trarray)/rounds, 'Average test reward = ', trarray[-1]/rounds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2cd4164dab9b> in <module>()
#       3 rounds = 100
#       4 for i in range(10):
# ----> 5     trarray.append(play_game(rounds))
#       6     print(i, ' sequence. Average test reward = ', np.average(trarray)/rounds, 'Average test reward = ', trarray[-1]/rounds)
#       7
#
# <ipython-input-8-15fdc68eedc8> in play_game(rounds)
#       5     for _ in range(0, rounds):
#       6         # Rendering for visualization
# ----> 7         env.render()
#       8
#       9         flat_state = np.reshape(state, [1, 3])
#
# /usr/local/lib/python3.7/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/pendulum.py in render(self, mode)
#      70     def render(self, mode='human'):
#      71         if self.viewer is None:
# ---> 72             from gym.envs.classic_control import rendering
#      73             self.viewer = rendering.Viewer(500, 500)
#      74             self.viewer.set_bounds(-2.2, 2.2, -2.2, 2.2)
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/rendering.py in <module>()
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in <module>()
#     233 elif compat_platform == 'darwin':
#     234     from .cocoa import CocoaConfig as Config
# --> 235 del base  # noqa: F821
#     236
#     237
#
# NameError: name 'base' is not defined

# %% [markdown]
# ## Run pretrained model
#
# In case you already trained a model or want to load the pretrained model for sanity checking use the following script (make sure you executed the necessary cells starting with the imports).
#
# - How does the performance change with the amount of trained iterations?
# - How can we measure performance to begin with?
# - Is it sufficient to start the play_game function a single time?
# - How can we make sure, that the evaluation is meaningful?

# %%
'''

- The performance varies with the change in the amount of trained iterations. It might improve or reduce with the amount.
- 
- No it is not sufficient to start the play_game function a single time. It is better to itterate the funtion.
- 

'''

# %%
env = gym.make('Pendulum-v0')

actionbinslist = create_action_bins(20)

# 'pendulum_model_[iterationstrained].h5' 
# iterationstrained: 100, 1000, 10000
model = load_model('pendulum_model_1000.h5')

'''
Is the next line meaningful for evaluation, if not, what can we do?

play_game(rounds=250)
'''

for i in range(10):
    play_game(rounds=250)
    
env.close()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-344a7944514a> in <module>()
#       5 # 'pendulum_model_[iterationstrained].h5'
#       6 # iterationstrained: 100, 1000, 10000
# ----> 7 model = load_model('pendulum_model_1000.h5')
#       8
#       9 '''
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: pendulum_model_1000.h5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# ## Next steps to take it from here
#
# - Implement a skip frame approach
# - Experiment with the discretization of the action bins (e.g. advantages and disadvantages of triadisation)
# - Experiment with exploration vs exploitation
#
# Send extended ipynb file to mark.schutera@kit.edu for the chance to get bonus points for the final project.
