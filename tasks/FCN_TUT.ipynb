# %% [markdown]
# # Applied Deep Learning Tutorial
# contact: Mark.schutera@kit.edu
# # Deep Learning Foundations
#
# ## Introduction
# In this tutorial, you will attempt to get a first understanding of neural networks and the tensorflow library. You will get an understanding of backpropagation, convolutional layers, fully connected layers, activation functions, loss functions, and bring all this together into your first neural network architecture.
#
# <img src="graphics/set_sails.jpg" width="700"><br>
# <center> Fig. 1: Setting sails for the deep learning journey. Image from [pixabay](https://pixabay.com/de/photos/) </center>

# %% [markdown]
# ## Back Propagation
#
# Backpropagation is the central part of iterative optimization. The backpropagation utilizes the derivative of each unit in the neural network starting with the determined error resulting from the loss function. With the chain rule the various units are connected to obtain the derivatives of the loss function through all layers. The resulting matrix shows you how each weight effects the output and its error. Thus, aiming to minimize the error the derivatives tell you in which direction to update the associated weights.
#
#
# Define an input vector x with two entries valued (0.2 and 0.4) and a fully connected weight matrix W with two units. The groundtruth should be defined as 1.
#
# \begin{align}
# 	x =\begin{bmatrix}
# 	0.2 \\ 0.4
# 	\end{bmatrix}
# \end{align}
#
# \begin{align}
# 	y = 1
# \end{align}

# %%
# We will first do some experiments in numpy, no worries there will be enough tensorflow soon.
import numpy as np

x = np.array([[0.2], [2]])
W = np.array([[-0.3, 0.8]])
y = 1

# %% [markdown]
# Next we need to define our architecture to reach the prediction of our one unit neural network, we split the equation in two functions so we can define the derivates partially in the next step:
#
# \begin{align}
# 	 f(x,W)= || W*x ||^2.
# \end{align}

# %%
def multiplication(W,x):
    q = np.dot(W,x)
    return q

def prediction(q):
    f_1 = np.square(q)
    y_pred = np.sum(f_1)
   
    return y_pred

# %% [markdown]
# To calculate the error we need to specify a loss function or objective function and our weight update step:

# %%
def update (W, grad_W, learning_rate):
    W = W - np.multiply(learning_rate , grad_W)
    return W

# %%
def prediction_loss(y_pred, y):
    error = y_pred - y
    loss = np.square(error)
    return loss

# %% [markdown]
# Now it is time to determine the partial derivatives of our neural network. We aim to determine the gradient of our function
# $f(x,W)$ dependent from the input values of our network $x$, and the networks parameters $W$.
#
# \begin{align}
# 	\frac{\partial f(x,W)}{\partial W}
# \end{align}
#
# \begin{align}
#     \frac{\partial f(x,W)}{\partial x}
# \end{align}
#
# By using the chain rule we can easily propagate the error through the local derivatives at each operation and unit.
#
# The derivative of the last stage of our unit can be written as:
# \begin{align}
# 	f(q)= ||q||^2 = q_{1}^2+...+q_{n}^2, \frac{\partial f(q)}{\partial q} = 2*q_{i}.
# \end{align}
#
# For the next node we have two variable inputs and so we have to calculate the local derivatives with respect to both $W$, since this is where we can adjust the weights.
# \begin{align}
# 	q = W*x
# \end{align}
#
# \begin{align}
#     \frac{\partial q_{k}}{\partial W_{i,j}}=x
# \end{align}
#
# With the chain rule, we can now backpropagate the error to those weights:
#
# \begin{align}
#     \frac{\partial f(x,W)}{\partial W} = \frac{\partial f(q)}{\partial q} * \frac{\partial q}{\partial W} = 2*q*x^{T}
# \end{align}

# %%
# Starting with the loss function
def gradient_loss(y_pred, y):
    grad_loss = 2 * (y_pred-y)
    return grad_loss

# Over the square operator
def gradient_prediction (q, grad_loss):
    grad_q = 2 * q * grad_loss
    return grad_q

# Finally to the multiplication of our inputs
def gradient_multiplication (x, grad_q):
    if len(x) == 1:
        grad_W = grad_q * x.T
    else:
        grad_W = np.dot(grad_q, x.T)
    return grad_W

# %% [markdown]
# Finally we bring everything together in our iterative weight update process, in our optimization routine for our neural network.

# %%
learning_rate = 1e-2

weightlist1 = []
weightlist2 = []
predictionlist = []
groundtruthlist = []

for t in range(10):
    
    weightlist1.append(W[0][0])
    weightlist2.append(W[0][1])
    
    # Forward pass
    q = multiplication(W,x)
    y_pred = prediction(q)
    loss = prediction_loss(y_pred, y)
    print("Training loss: ", loss)
    
    # Backpropagation
    grad_loss = gradient_loss(y_pred, y)
    grad_q = gradient_prediction (q, grad_loss)
    grad_W = gradient_multiplication (x, grad_q)
    W = update (W, grad_W, learning_rate)
    predictionlist.append(y_pred)
    groundtruthlist.append(y)
    print("Current prediction: ", y_pred)
# Out:
# Training loss:  1.8812865599999997
# Current prediction:  2.3716
# Training loss:  0.19077793096573217
# Current prediction:  1.4367813308347006
# Training loss:  0.05813516022627628
# Current prediction:  1.2411123394318015
# Training loss:  0.021397771751449256
# Current prediction:  1.14627977218826
# Training loss:  0.00859828235134978
# Current prediction:  1.0927269235516297
# Training loss:  0.003626927562396606
# Current prediction:  1.0602239783009775
# Training loss:  0.0015751203015956998
# Current prediction:  1.0396877852946684
# Training loss:  0.0006966633103661769
# Current prediction:  1.0263943802800175
# Training loss:  0.0003117777091850404
# Current prediction:  1.0176572282418572
# Training loss:  0.00014061053282360107
# Current prediction:  1.0118579312202256

# %%
# How do the weights change with respect to the given input? Elaborate?

import matplotlib.pyplot as plt
plt.plot(weightlist1, weightlist2)
plt.xlabel('Weight 1')
plt.ylabel('Weight 2')
plt.show()

# %%
plt.plot(predictionlist, groundtruthlist)
plt.xlabel('Prediction')
plt.ylabel('Groundtruth')
plt.show()

# %% [markdown]
# # TensorFlow bring it on!
# Now we are going to get our hands dirty with TensorFlow, where most of the hard work is already done for you. This way we can finally focus on "adding layers" and "going deeper".
#
# ## Optimization
# First we concentrate on optimization, this is basically mirroring what we did with numpy a few cell above. This time we will implement a full neural network unit, including an activation function and also we are adding a third input, introducing a bias for the unit.

# %%
import tensorflow as tf
import numpy as np

# For reproducability
np.random.seed(2)

# %%
# Neural Network architecture
n_input = 3
n_output = 1
n_units = 1

# Training parameters
n_updates = 10


# Define graph / network
weights = {
    'h1': tf.Variable(np.reshape([np.float32(2.0), np.float32(2.0), np.float32(2.0)], (3, 1))),
    # 'h1': tf.Variable(tf.random_normal([n_input, n_units])),
}

biases = {
    'b1': tf.Variable(np.reshape([np.float32(4.0)], (1, 1))),
    # 'b1': tf.Variable(tf.random_normal([n_units])),
}

# This is where we design our unit
def unit(x0, weights, biases):
    # unit / neuron structure
    layer_1 = tf.add(tf.matmul(tf.cast(x0, tf.float32), weights['h1']), biases['b1'])
    # activation function
    y_pred = tf.nn.relu(layer_1)
    return y_pred


# Input
x = tf.Variable(np.reshape([1.0, 1.0, 3.0], (1, 3)))
# predicted output
y_pred = unit(x, weights, biases)
# Expected output
y_gt = tf.Variable(np.reshape([10.0], (1, 1)))

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %%
#Errors while running this and the next cell due to change in tensorflow verion

cost = tf.losses.mean_squared_error(y_gt, y_pred)

# 1. Stochastic gradient descent
#opt = tf.train.GradientDescentOptimizer(learning_rate=0.0001)

# 2. Momentum optimizer
#opt = tf.train.MomentumOptimizer(learning_rate=0.0001, momentum=0.75)

# 3. Adaptive momentum optimizer
# opt = tf.train.AdamOptimizer(learning_rate=0.0001)

# 4. Adaptive momentum optimizer with adjusted initial learning rate
# opt = tf.train.AdamOptimizer(learning_rate=0.1)


train = opt.minimize(cost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b78bc8b88f1c> in <module>()
#      16
#      17
# ---> 18 train = opt.minimize(cost)
#
# NameError: name 'opt' is not defined

# %%
# Run graph
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for _ in range(n_updates):
        sess.run(train)
        grad, variable = sess.run(opt.compute_gradients(cost))[0]

        print('Gradient', np.reshape(grad, 3))
        print('Weights:', np.reshape(sess.run(weights['h1']), 3))
        print('Biases:', sess.run(biases['b1']))
        print('Prediction', y_pred.eval())
        print('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1b0bc90cda48> in <module>()
#       1 # Run graph
# ----> 2 with tf.Session() as sess:
#       3     sess.run(tf.global_variables_initializer())
#       4     for _ in range(n_updates):
#       5         sess.run(train)
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %% [markdown]
# Try the different backpropagation approaches and see whether you can reproduce the findings presented in the lecture.
#
# Notice the design of tensorflow, which first designs the model and then calls a session where the placeholders are filled and the forward and backward pass are executed.

# %% [markdown]
# ## Regularization
# Next we will get an intuition for regularization approaches (Evaluate the different designs 0. to 2.)  Also we are working with the Keras library, which is based on TensorFlow and introduces a more pythonic feeling. Do you have a notion why I would say so?

# %%
import tensorflow as tf

# Define model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),

  # Design 0. without regularization:
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),

  # Design 1. L2 Parameter norm penalty by kernel regularizer:
  #tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  #tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  #tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  #tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),

  # Design 2. Dropout:
  # tf.keras.layers.Dense(512, activation=tf.nn.relu),
  # tf.keras.layers.Dropout(0.5),
  # tf.keras.layers.Dense(512, activation=tf.nn.relu),
  # tf.keras.layers.Dropout(0.5),
  # tf.keras.layers.Dense(512, activation=tf.nn.relu),
  # tf.keras.layers.Dropout(0.5),
  # tf.keras.layers.Dense(512, activation=tf.nn.relu),
  # tf.keras.layers.Dropout(0.5),

  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
# Define training parameters, feel free to play with the different optimizers as well.
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Load training data (reduce training data to 10k samples)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_validation, y_validation) = mnist.load_data()

# Normalize input images (comply with activation function)
x_train, x_validation = x_train / 255.0, x_validation / 255.0

# %%
# 3. Augmentation
# x_train = x_train.reshape(x_train.shape[0], 1, 28, 28)
# datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
#                                                                 featurewise_center=True,
#                                                                 featurewise_std_normalization=True,
#                                                                 rotation_range=20,
#                                                                 width_shift_range=0.2,
#                                                                 height_shift_range=0.2,
#                                                                 horizontal_flip=False
#                                                                 )
#
# for e in range(10):
#     print('Epoch', e)
#     batches = 0
#     for x_batch, y_batch in datagenerator.flow(x_train, y_train, batch_size=32):
#         model.fit(np.reshape(x_batch, (-1, 28, 28)), y_batch, shuffle=True)
#         batches += 1
#         if batches >= len(x_train) / 32:
#             # we need to break the loop by hand because
#             # the generator loops indefinitely
#             break

# 4. Early stopping (usually you should monitor the validation accuracy)
# es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
#                                      min_delta=0,
#                                      patience=1,
#                                      mode='auto'
#                                      )
#
# Fit model on training data (with callback)
# model.fit(x_train, 
#          y_train, 
#          epochs=10, 
#          shuffle=True, 
#          callbacks=[es],
#          validation_data=(x_validation, y_validation)
#         )

# Fit model on training data (without regularization)
model.fit(x_train, y_train, epochs=10, shuffle=True)

# Evaluate performance on validation set
_, validation_acc = model.evaluate(x_validation, y_validation)
print('validation accuracy:', validation_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3436 - accuracy: 0.8941
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1049 - accuracy: 0.9702
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0731 - accuracy: 0.9782
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0574 - accuracy: 0.9826
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0516 - accuracy: 0.9854
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0390 - accuracy: 0.9889
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0373 - accuracy: 0.9895
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0351 - accuracy: 0.9903
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0304 - accuracy: 0.9916
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0287 - accuracy: 0.9918
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1225 - accuracy: 0.9748
# validation accuracy: 0.9747999906539917

# %% [markdown]
# ## Next steps to take it from here
#
# - Keep in mind that [MNIST](http://yann.lecun.com/exdb/mnist/) is the "Hello world" of machine learning, this is the go-to-dataset if you are in need for a toy problem. Most new ideas in machine learning are presented by the aid of MNIST, make sure that you familiarize yourself with the dataset and its characteristics.
# - Try different regularization approaches and their influence.
# - Can you think of a good task to introduce Convolutional Neural Networks, including receptive field, strides, semantic information, and so on? (Send your jupyter notebook to mark.schutera@kit.edu for a chance to earn bonus points).

# %%
#L2 parameter norm penalties:

# Define model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Define training parameters, SGD optimizer.
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Load training data (reduce training data to 10k samples)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_validation, y_validation) = mnist.load_data()

# Normalize input images (comply with activation function)
x_train, x_validation = x_train / 255.0, x_validation / 255.0

# Fit model on training data (without regularization)
model.fit(x_train, y_train, epochs=10, shuffle=True)

# Evaluate performance on validation set
_, validation_acc = model.evaluate(x_validation, y_validation)
print('validation accuracy:', validation_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 19.3368 - accuracy: 0.7125
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 9.1685 - accuracy: 0.9109
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.6777 - accuracy: 0.9218
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.5463 - accuracy: 0.9295
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.5305 - accuracy: 0.9331
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.0409 - accuracy: 0.9354
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7919 - accuracy: 0.9417
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6678 - accuracy: 0.9458
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6041 - accuracy: 0.9461
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5710 - accuracy: 0.9477
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.9489
# validation accuracy: 0.9488999843597412

# %%
#Drop out 0.5

# Define model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  # Design 2. Dropout:
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Define training parameters, RMSprop optimizer.
model.compile(optimizer='RMSprop',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Load training data (reduce training data to 10k samples)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_validation, y_validation) = mnist.load_data()

# Normalize input images (comply with activation function)
x_train, x_validation = x_train / 255.0, x_validation / 255.0

# Fit model on training data (without regularization)
model.fit(x_train, y_train, epochs=10, shuffle=True)

# Evaluate performance on validation set
_, validation_acc = model.evaluate(x_validation, y_validation)
print('validation accuracy:', validation_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7365 - accuracy: 0.7669
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3777 - accuracy: 0.9259
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4341 - accuracy: 0.9289
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5134 - accuracy: 0.9247
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6157 - accuracy: 0.9197
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7214 - accuracy: 0.9193
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8008 - accuracy: 0.9121
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9129 - accuracy: 0.9037
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9201 - accuracy: 0.9001
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.0370 - accuracy: 0.8888
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3570 - accuracy: 0.9342
# validation accuracy: 0.9341999888420105

# %%
#Augmentation only 2 epochs
# Define model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),

  # Design 0. without regularization:
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Define training parameters, feel free to play with the different optimizers as well.
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Load training data (reduce training data to 10k samples)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_validation, y_validation) = mnist.load_data()

# Normalize input images (comply with activation function)
x_train, x_validation = x_train / 255.0, x_validation / 255.0

# 3. Augmentation
x_train = x_train.reshape(x_train.shape[0], 1, 28, 28)
datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                                                                featurewise_center=True,
                                                                featurewise_std_normalization=True,
                                                                rotation_range=20,
                                                                width_shift_range=0.2,
                                                                height_shift_range=0.2,
                                                                horizontal_flip=False
                                                                )
for e in range(2):
    print('Epoch', e)
    batches = 0
    for x_batch, y_batch in datagenerator.flow(x_train, y_train, batch_size=32):
        model.fit(np.reshape(x_batch, (-1, 28, 28)), y_batch, shuffle=True)
        batches += 1
        print(batches)
        if batches >= len(x_train) / 32:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break

# Evaluate performance on validation set
_, validation_acc = model.evaluate(x_validation, y_validation)
print('validation accuracy:', validation_acc)
# Out:
# Epoch 0
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/numpy_array_iterator.py:136: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (60000, 1, 28, 28) (28 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Streaming output truncated to the last 5000 lines.
# 1252
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9062
# 1253
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1643 - accuracy: 0.9375
# 1254
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6973 - accuracy: 0.8438
# 1255
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1651 - accuracy: 0.9375
# 1256
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2685 - accuracy: 0.9375
# 1257
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.9375
# 1258
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2396 - accuracy: 0.9062
# 1259
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.9062
# 1260
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2498 - accuracy: 0.9375
# 1261
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2986 - accuracy: 0.8438
# 1262
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1770 - accuracy: 0.9375
# 1263
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2394 - accuracy: 0.9062
# 1264
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4020 - accuracy: 0.8750
# 1265
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2834 - accuracy: 0.8750
# 1266
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4877 - accuracy: 0.9375
# 1267
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3069 - accuracy: 0.9375
# 1268
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2805 - accuracy: 0.9062
# 1269
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1782 - accuracy: 0.9688
# 1270
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 1.0000
# 1271
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3005 - accuracy: 0.9062
# 1272
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.9375
# 1273
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2925 - accuracy: 0.8750
# 1274
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9688
# 1275
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2896 - accuracy: 0.9375
# 1276
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2773 - accuracy: 0.9062
# 1277
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0824 - accuracy: 0.9688
# 1278
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5973 - accuracy: 0.8438
# 1279
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5716 - accuracy: 0.8438
# 1280
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2893 - accuracy: 0.8750
# 1281
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.9688
# 1282
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2882 - accuracy: 0.8750
# 1283
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8339 - accuracy: 0.8438
# 1284
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2463 - accuracy: 0.9375
# 1285
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1887 - accuracy: 0.9375
# 1286
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3917 - accuracy: 0.9062
# 1287
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3216 - accuracy: 0.8750
# 1288
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2597 - accuracy: 0.9062
# 1289
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1695 - accuracy: 0.9375
# 1290
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2089 - accuracy: 0.9688
# 1291
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2420 - accuracy: 0.9375
# 1292
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3855 - accuracy: 0.9375
# 1293
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1749 - accuracy: 0.9375
# 1294
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2829 - accuracy: 0.9375
# 1295
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.9375
# 1296
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2981 - accuracy: 0.9062
# 1297
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1807 - accuracy: 0.9688
# 1298
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2162 - accuracy: 0.9375
# 1299
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 1.0000
# 1300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2346 - accuracy: 0.8750
# 1301
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2694 - accuracy: 0.9062
# 1302
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2177 - accuracy: 0.9688
# 1303
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1733 - accuracy: 0.9375
# 1304
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2818 - accuracy: 0.9688
# 1305
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4733 - accuracy: 0.8438
# 1306
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2158 - accuracy: 0.9688
# 1307
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9688
# 1308
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2616 - accuracy: 0.9375
# 1309
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9688
# 1310
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9688
# 1311
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9375
# 1312
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2229 - accuracy: 0.9375
# 1313
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3731 - accuracy: 0.8750
# 1314
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 1.0000
# 1315
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1958 - accuracy: 0.9375
# 1316
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2433 - accuracy: 0.9062
# 1317
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0828 - accuracy: 1.0000
# 1318
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1407 - accuracy: 0.9375
# 1319
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2827 - accuracy: 0.8750
# 1320
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1692 - accuracy: 0.9375
# 1321
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9375
# 1322
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3815 - accuracy: 0.9062
# 1323
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2217 - accuracy: 0.9375
# 1324
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9688
# 1325
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2040 - accuracy: 0.9062
# 1326
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.9062
# 1327
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2766 - accuracy: 0.9375
# 1328
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9375
# 1329
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2358 - accuracy: 0.9688
# 1330
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2807 - accuracy: 0.9062
# 1331
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1089 - accuracy: 0.9688
# 1332
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 1.0000
# 1333
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9688
# 1334
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1934 - accuracy: 0.9062
# 1335
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2526 - accuracy: 0.9688
# 1336
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.9375
# 1337
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5994 - accuracy: 0.8438
# 1338
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3981 - accuracy: 0.9375
# 1339
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3243 - accuracy: 0.8750
# 1340
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1859 - accuracy: 0.9375
# 1341
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2135 - accuracy: 0.9062
# 1342
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9375
# 1343
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2948 - accuracy: 0.9062
# 1344
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1951 - accuracy: 0.9062
# 1345
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5266 - accuracy: 0.8125
# 1346
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1173 - accuracy: 0.9688
# 1347
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 0.9688
# 1348
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1975 - accuracy: 0.9688
# 1349
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5584 - accuracy: 0.9062
# 1350
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.9375
# 1351
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5523 - accuracy: 0.8750
# 1352
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2619 - accuracy: 0.9062
# 1353
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1521 - accuracy: 0.9688
# 1354
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3240 - accuracy: 0.9375
# 1355
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1194 - accuracy: 0.9688
# 1356
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1645 - accuracy: 0.9375
# 1357
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3927 - accuracy: 0.8438
# 1358
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2403 - accuracy: 0.9375
# 1359
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3460 - accuracy: 0.9062
# 1360
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2144 - accuracy: 0.9375
# 1361
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2411 - accuracy: 0.8750
# 1362
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9688
# 1363
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4288 - accuracy: 0.9375
# 1364
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9688
# 1365
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1814 - accuracy: 0.9375
# 1366
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2052 - accuracy: 0.9062
# 1367
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2143 - accuracy: 0.9375
# 1368
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3296 - accuracy: 0.8438
# 1369
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2875 - accuracy: 0.9062
# 1370
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2931 - accuracy: 0.9062
# 1371
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9688
# 1372
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1663 - accuracy: 0.9688
# 1373
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5237 - accuracy: 0.8750
# 1374
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9688
# 1375
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2462 - accuracy: 0.9688
# 1376
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3026 - accuracy: 0.9375
# 1377
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0902 - accuracy: 0.9688
# 1378
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.9062
# 1379
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2262 - accuracy: 0.9062
# 1380
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1067 - accuracy: 0.9375
# 1381
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3692 - accuracy: 0.8750
# 1382
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1655 - accuracy: 0.9375
# 1383
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1785 - accuracy: 0.9375
# 1384
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.9688
# 1385
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3881 - accuracy: 0.9062
# 1386
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1688 - accuracy: 0.9375
# 1387
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3316 - accuracy: 0.9062
# 1388
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1678 - accuracy: 0.9062
# 1389
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1400 - accuracy: 0.9688
# 1390
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3312 - accuracy: 0.9062
# 1391
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.8750
# 1392
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5413 - accuracy: 0.8438
# 1393
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2788 - accuracy: 0.9062
# 1394
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2811 - accuracy: 0.8750
# 1395
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4026 - accuracy: 0.8750
# 1396
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.9688
# 1397
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2636 - accuracy: 0.9688
# 1398
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 1.0000
# 1399
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2239 - accuracy: 0.8750
# 1400
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4042 - accuracy: 0.8438
# 1401
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3941 - accuracy: 0.8438
# 1402
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2536 - accuracy: 0.9688
# 1403
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5713 - accuracy: 0.8438
# 1404
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 1.0000
# 1405
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9688
# 1406
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2663 - accuracy: 0.8750
# 1407
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1112 - accuracy: 0.9688
# 1408
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2627 - accuracy: 0.9062
# 1409
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1081 - accuracy: 0.9688
# 1410
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.8750
# 1411
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3475 - accuracy: 0.9062
# 1412
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0511 - accuracy: 1.0000
# 1413
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.9688
# 1414
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2605 - accuracy: 0.9375
# 1415
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1677 - accuracy: 0.9375
# 1416
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1759 - accuracy: 0.9688
# 1417
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2573 - accuracy: 0.8750
# 1418
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8750
# 1419
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9375
# 1420
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1958 - accuracy: 0.9062
# 1421
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9375
# 1422
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1636 - accuracy: 0.9375
# 1423
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4072 - accuracy: 0.9375
# 1424
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1627 - accuracy: 0.9375
# 1425
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6704 - accuracy: 0.8125
# 1426
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2093 - accuracy: 0.9375
# 1427
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1326 - accuracy: 0.9688
# 1428
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2028 - accuracy: 0.9688
# 1429
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2343 - accuracy: 0.9688
# 1430
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7448 - accuracy: 0.8438
# 1431
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8750
# 1432
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.9688
# 1433
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3839 - accuracy: 0.8750
# 1434
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1491 - accuracy: 0.9688
# 1435
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2038 - accuracy: 0.9375
# 1436
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2146 - accuracy: 0.9062
# 1437
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1408 - accuracy: 0.9375
# 1438
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1454 - accuracy: 0.9375
# 1439
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.9688
# 1440
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3265 - accuracy: 0.9062
# 1441
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9375
# 1442
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1500 - accuracy: 0.9062
# 1443
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1467 - accuracy: 0.9688
# 1444
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1062 - accuracy: 0.9688
# 1445
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1266 - accuracy: 0.9688
# 1446
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2387 - accuracy: 0.9062
# 1447
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1337 - accuracy: 0.9688
# 1448
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2207 - accuracy: 0.9062
# 1449
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2758 - accuracy: 0.9375
# 1450
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2840 - accuracy: 0.9062
# 1451
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3322 - accuracy: 0.9688
# 1452
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9375
# 1453
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3253 - accuracy: 0.9062
# 1454
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0672 - accuracy: 0.9688
# 1455
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1501 - accuracy: 1.0000
# 1456
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1292 - accuracy: 0.9375
# 1457
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1544 - accuracy: 0.9688
# 1458
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2045 - accuracy: 0.9375
# 1459
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3765 - accuracy: 0.9062
# 1460
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1682 - accuracy: 0.9688
# 1461
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1612 - accuracy: 0.9375
# 1462
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 1.0000
# 1463
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0709 - accuracy: 0.9688
# 1464
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1183 - accuracy: 0.9688
# 1465
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9688
# 1466
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9688
# 1467
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.9375
# 1468
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3001 - accuracy: 0.9375
# 1469
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4355 - accuracy: 0.9062
# 1470
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 1.0000
# 1471
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.9375
# 1472
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.8438
# 1473
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4708 - accuracy: 0.8750
# 1474
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2596 - accuracy: 0.8750
# 1475
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2038 - accuracy: 0.9375
# 1476
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3830 - accuracy: 0.8750
# 1477
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0633 - accuracy: 0.9688
# 1478
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0696 - accuracy: 1.0000
# 1479
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3216 - accuracy: 0.9062
# 1480
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2618 - accuracy: 0.8750
# 1481
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2434 - accuracy: 0.9062
# 1482
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1551 - accuracy: 0.9688
# 1483
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4253 - accuracy: 0.8750
# 1484
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2738 - accuracy: 0.9062
# 1485
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3723 - accuracy: 0.9062
# 1486
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 0.9688
# 1487
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9062
# 1488
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.9688
# 1489
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.8750
# 1490
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9375
# 1491
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 1.0000
# 1492
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3854 - accuracy: 0.9688
# 1493
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5464 - accuracy: 0.8750
# 1494
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1787 - accuracy: 0.9688
# 1495
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2592 - accuracy: 0.9062
# 1496
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9688
# 1497
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4160 - accuracy: 0.8750
# 1498
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1775 - accuracy: 0.9062
# 1499
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6097 - accuracy: 0.8438
# 1500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1692 - accuracy: 0.9688
# 1501
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9375
# 1502
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1527 - accuracy: 0.9375
# 1503
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4428 - accuracy: 0.9062
# 1504
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2187 - accuracy: 0.8750
# 1505
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.8750
# 1506
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2771 - accuracy: 0.9062
# 1507
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3778 - accuracy: 0.8750
# 1508
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1620 - accuracy: 0.9688
# 1509
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3598 - accuracy: 0.9062
# 1510
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2772 - accuracy: 0.8750
# 1511
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2922 - accuracy: 0.9375
# 1512
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2213 - accuracy: 0.9062
# 1513
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1864 - accuracy: 0.9375
# 1514
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.9375
# 1515
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2794 - accuracy: 0.9062
# 1516
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9375
# 1517
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2284 - accuracy: 0.8750
# 1518
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1707 - accuracy: 0.9062
# 1519
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1591 - accuracy: 0.9375
# 1520
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1815 - accuracy: 0.9062
# 1521
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2446 - accuracy: 0.8750
# 1522
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1511 - accuracy: 0.9375
# 1523
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2850 - accuracy: 0.9062
# 1524
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2530 - accuracy: 0.9375
# 1525
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5819 - accuracy: 0.8125
# 1526
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9375
# 1527
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1486 - accuracy: 0.9688
# 1528
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3079 - accuracy: 0.9062
# 1529
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0952 - accuracy: 1.0000
# 1530
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2714 - accuracy: 0.9688
# 1531
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1091 - accuracy: 0.9375
# 1532
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4169 - accuracy: 0.8750
# 1533
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1640 - accuracy: 0.9688
# 1534
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4886 - accuracy: 0.8438
# 1535
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 1.0000
# 1536
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3514 - accuracy: 0.9062
# 1537
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3376 - accuracy: 0.8750
# 1538
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2672 - accuracy: 0.9688
# 1539
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2578 - accuracy: 0.9062
# 1540
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1759 - accuracy: 0.9375
# 1541
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4766 - accuracy: 0.8438
# 1542
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3353 - accuracy: 0.8750
# 1543
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 0.9688
# 1544
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9688
# 1545
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1918 - accuracy: 0.9062
# 1546
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3796 - accuracy: 0.8750
# 1547
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1939 - accuracy: 0.9375
# 1548
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9375
# 1549
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3182 - accuracy: 0.9062
# 1550
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1121 - accuracy: 0.9375
# 1551
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9688
# 1552
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2553 - accuracy: 0.9688
# 1553
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9688
# 1554
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1330 - accuracy: 0.9688
# 1555
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1494 - accuracy: 0.9688
# 1556
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2096 - accuracy: 0.9062
# 1557
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3662 - accuracy: 0.9375
# 1558
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2943 - accuracy: 0.9062
# 1559
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1395 - accuracy: 0.9688
# 1560
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9688
# 1561
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1433 - accuracy: 0.9688
# 1562
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9688
# 1563
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2507 - accuracy: 0.9062
# 1564
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3310 - accuracy: 0.9375
# 1565
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1927 - accuracy: 0.9688
# 1566
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.9688
# 1567
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2175 - accuracy: 0.9688
# 1568
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1491 - accuracy: 0.9375
# 1569
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4148 - accuracy: 0.9062
# 1570
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2488 - accuracy: 0.9688
# 1571
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4726 - accuracy: 0.9062
# 1572
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2841 - accuracy: 0.9375
# 1573
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1468 - accuracy: 0.9375
# 1574
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5197 - accuracy: 0.9062
# 1575
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3306 - accuracy: 0.9062
# 1576
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1261 - accuracy: 0.9688
# 1577
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9688
# 1578
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9375
# 1579
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2008 - accuracy: 0.9062
# 1580
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9375
# 1581
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4951 - accuracy: 0.8438
# 1582
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1008 - accuracy: 0.9688
# 1583
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1410 - accuracy: 0.9062
# 1584
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1972 - accuracy: 0.9688
# 1585
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2390 - accuracy: 0.9375
# 1586
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2809 - accuracy: 0.9375
# 1587
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3227 - accuracy: 0.9375
# 1588
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3116 - accuracy: 0.9375
# 1589
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3146 - accuracy: 0.9375
# 1590
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3868 - accuracy: 0.9062
# 1591
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4016 - accuracy: 0.9062
# 1592
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2455 - accuracy: 0.9062
# 1593
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1407 - accuracy: 0.9375
# 1594
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3525 - accuracy: 0.9375
# 1595
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 1.0000
# 1596
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1772 - accuracy: 0.9375
# 1597
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3060 - accuracy: 0.9375
# 1598
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2103 - accuracy: 0.9062
# 1599
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2517 - accuracy: 0.8750
# 1600
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2470 - accuracy: 0.8750
# 1601
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1347 - accuracy: 0.9688
# 1602
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9688
# 1603
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2740 - accuracy: 0.9375
# 1604
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2179 - accuracy: 0.9375
# 1605
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1257 - accuracy: 0.9688
# 1606
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2369 - accuracy: 0.8750
# 1607
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2458 - accuracy: 0.9688
# 1608
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9375
# 1609
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0530 - accuracy: 1.0000
# 1610
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2497 - accuracy: 0.9375
# 1611
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2798 - accuracy: 0.9062
# 1612
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2516 - accuracy: 0.9062
# 1613
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3871 - accuracy: 0.8750
# 1614
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1411 - accuracy: 0.9375
# 1615
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3978 - accuracy: 0.9062
# 1616
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1044 - accuracy: 0.9688
# 1617
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.9062
# 1618
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0658 - accuracy: 0.9688
# 1619
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2660 - accuracy: 0.9062
# 1620
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2311 - accuracy: 0.9062
# 1621
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4606 - accuracy: 0.9062
# 1622
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 0.9688
# 1623
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1863 - accuracy: 0.9375
# 1624
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1053 - accuracy: 0.9375
# 1625
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1498 - accuracy: 0.9688
# 1626
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 1.0000
# 1627
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.9062
# 1628
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1958 - accuracy: 0.9062
# 1629
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2983 - accuracy: 0.9062
# 1630
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3386 - accuracy: 0.9062
# 1631
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 1.0000
# 1632
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1698 - accuracy: 0.9688
# 1633
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9688
# 1634
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4476 - accuracy: 0.8438
# 1635
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1251 - accuracy: 0.9688
# 1636
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 0.9688
# 1637
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1400 - accuracy: 0.9688
# 1638
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.9375
# 1639
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.9062
# 1640
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 1.0000
# 1641
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4063 - accuracy: 0.9062
# 1642
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2552 - accuracy: 0.9375
# 1643
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2717 - accuracy: 0.9375
# 1644
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1952 - accuracy: 0.9062
# 1645
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2795 - accuracy: 0.9375
# 1646
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.9688
# 1647
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3693 - accuracy: 0.9062
# 1648
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 1.0000
# 1649
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3505 - accuracy: 0.9062
# 1650
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1644 - accuracy: 0.9375
# 1651
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9062
# 1652
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1480 - accuracy: 0.9062
# 1653
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.9688
# 1654
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2177 - accuracy: 0.9375
# 1655
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.9062
# 1656
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2599 - accuracy: 0.9375
# 1657
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1050 - accuracy: 0.9375
# 1658
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4774 - accuracy: 0.9062
# 1659
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4402 - accuracy: 0.8438
# 1660
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8125
# 1661
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3216 - accuracy: 0.9375
# 1662
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3390 - accuracy: 0.9062
# 1663
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0518 - accuracy: 1.0000
# 1664
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6580 - accuracy: 0.7812
# 1665
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2740 - accuracy: 0.9062
# 1666
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2470 - accuracy: 0.9062
# 1667
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2119 - accuracy: 0.9062
# 1668
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4850 - accuracy: 0.8750
# 1669
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 1.0000
# 1670
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9688
# 1671
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2860 - accuracy: 0.9375
# 1672
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1949 - accuracy: 0.9688
# 1673
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1036 - accuracy: 0.9688
# 1674
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1293 - accuracy: 0.9688
# 1675
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3894 - accuracy: 0.8750
# 1676
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1356 - accuracy: 0.9375
# 1677
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2967 - accuracy: 0.9062
# 1678
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9688
# 1679
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2200 - accuracy: 0.9688
# 1680
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1959 - accuracy: 0.9375
# 1681
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2585 - accuracy: 0.8750
# 1682
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1192 - accuracy: 0.9375
# 1683
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1630 - accuracy: 0.9375
# 1684
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.8750
# 1685
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.9062
# 1686
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2757 - accuracy: 0.9062
# 1687
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1466 - accuracy: 0.9688
# 1688
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1809 - accuracy: 0.9688
# 1689
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3203 - accuracy: 0.9062
# 1690
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3629 - accuracy: 0.9375
# 1691
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9688
# 1692
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3872 - accuracy: 0.9062
# 1693
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1614 - accuracy: 0.9375
# 1694
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1119 - accuracy: 0.9688
# 1695
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.9375
# 1696
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1081 - accuracy: 1.0000
# 1697
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1476 - accuracy: 0.9688
# 1698
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.8750
# 1699
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1352 - accuracy: 0.9688
# 1700
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9688
# 1701
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9688
# 1702
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9688
# 1703
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4279 - accuracy: 0.8438
# 1704
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2769 - accuracy: 0.9375
# 1705
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9375
# 1706
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2828 - accuracy: 0.9375
# 1707
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 1.0000
# 1708
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4129 - accuracy: 0.8750
# 1709
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9375
# 1710
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1636 - accuracy: 0.9375
# 1711
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 0.8438
# 1712
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1530 - accuracy: 0.9375
# 1713
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1975 - accuracy: 0.9688
# 1714
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2778 - accuracy: 0.9062
# 1715
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4398 - accuracy: 0.9062
# 1716
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1355 - accuracy: 0.9688
# 1717
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9688
# 1718
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9688
# 1719
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0721 - accuracy: 1.0000
# 1720
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1749 - accuracy: 0.9375
# 1721
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 1.0000
# 1722
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.9062
# 1723
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2844 - accuracy: 0.9062
# 1724
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1654 - accuracy: 0.9688
# 1725
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2794 - accuracy: 0.9375
# 1726
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 1.0000
# 1727
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1288 - accuracy: 0.9375
# 1728
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.9375
# 1729
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2991 - accuracy: 0.9375
# 1730
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9688
# 1731
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 1.0000
# 1732
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5598 - accuracy: 0.7812
# 1733
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5964 - accuracy: 0.9062
# 1734
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3278 - accuracy: 0.8750
# 1735
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2629 - accuracy: 0.9375
# 1736
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3110 - accuracy: 0.9062
# 1737
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1537 - accuracy: 0.9062
# 1738
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 0.9375
# 1739
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1568 - accuracy: 0.9688
# 1740
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1896 - accuracy: 0.9375
# 1741
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4100 - accuracy: 0.8750
# 1742
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1953 - accuracy: 0.8750
# 1743
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 1.0000
# 1744
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2527 - accuracy: 0.9375
# 1745
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3486 - accuracy: 0.9375
# 1746
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9375
# 1747
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5004 - accuracy: 0.8750
# 1748
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2895 - accuracy: 0.9062
# 1749
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.9375
# 1750
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0482 - accuracy: 1.0000
# 1751
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1901 - accuracy: 0.9375
# 1752
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1698 - accuracy: 0.9688
# 1753
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2396 - accuracy: 0.9062
# 1754
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2344 - accuracy: 0.9688
# 1755
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1182 - accuracy: 0.9688
# 1756
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1339 - accuracy: 0.9688
# 1757
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1024 - accuracy: 0.9688
# 1758
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3134 - accuracy: 0.9062
# 1759
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2331 - accuracy: 0.8750
# 1760
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3584 - accuracy: 0.9062
# 1761
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3981 - accuracy: 0.8438
# 1762
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1913 - accuracy: 0.9375
# 1763
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 1.0000
# 1764
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1072 - accuracy: 0.9375
# 1765
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1146 - accuracy: 0.9688
# 1766
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1970 - accuracy: 0.9375
# 1767
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1371 - accuracy: 0.9688
# 1768
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2089 - accuracy: 0.9062
# 1769
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2047 - accuracy: 0.9688
# 1770
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3121 - accuracy: 0.8750
# 1771
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9688
# 1772
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2622 - accuracy: 0.9062
# 1773
# ...
# 1699
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1205 - accuracy: 0.9375
# 1700
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1364 - accuracy: 0.9688
# 1701
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0399 - accuracy: 1.0000
# 1702
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0726 - accuracy: 0.9688
# 1703
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1634 - accuracy: 0.9375
# 1704
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 0.9688
# 1705
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2372 - accuracy: 0.9375
# 1706
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2960 - accuracy: 0.9688
# 1707
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9688
# 1708
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1165 - accuracy: 0.9688
# 1709
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9688
# 1710
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 1.0000
# 1711
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0754 - accuracy: 0.9688
# 1712
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3870 - accuracy: 0.9375
# 1713
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2750 - accuracy: 0.9375
# 1714
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.9062
# 1715
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 1.0000
# 1716
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3196 - accuracy: 0.8438
# 1717
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# 1718
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1603 - accuracy: 0.9375
# 1719
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9375
# 1720
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2471 - accuracy: 0.9062
# 1721
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0657 - accuracy: 0.9688
# 1722
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4783 - accuracy: 0.9062
# 1723
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2728 - accuracy: 0.9375
# 1724
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3900 - accuracy: 0.8750
# 1725
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9688
# 1726
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7609 - accuracy: 0.8750
# 1727
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9688
# 1728
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2662 - accuracy: 0.9062
# 1729
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1316 - accuracy: 0.9062
# 1730
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2878 - accuracy: 0.9062
# 1731
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 1.0000
# 1732
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1172 - accuracy: 0.9688
# 1733
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.9375
# 1734
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2565 - accuracy: 0.9062
# 1735
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1424 - accuracy: 0.9688
# 1736
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9688
# 1737
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 1.0000
# 1738
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9375
# 1739
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 1.0000
# 1740
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0892 - accuracy: 0.9688
# 1741
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 1.0000
# 1742
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1077 - accuracy: 1.0000
# 1743
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0967 - accuracy: 0.9688
# 1744
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1468 - accuracy: 0.9688
# 1745
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2822 - accuracy: 0.8750
# 1746
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3502 - accuracy: 0.9062
# 1747
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2567 - accuracy: 0.9375
# 1748
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1415 - accuracy: 0.9375
# 1749
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9688
# 1750
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2344 - accuracy: 0.9375
# 1751
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.9375
# 1752
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3291 - accuracy: 0.9062
# 1753
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1331 - accuracy: 0.9375
# 1754
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2485 - accuracy: 0.8750
# 1755
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0779 - accuracy: 0.9688
# 1756
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1267 - accuracy: 0.9688
# 1757
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1179 - accuracy: 0.9375
# 1758
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4312 - accuracy: 0.8750
# 1759
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1812 - accuracy: 0.9375
# 1760
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2356 - accuracy: 0.9062
# 1761
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4186 - accuracy: 0.8750
# 1762
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4973 - accuracy: 0.9375
# 1763
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4916 - accuracy: 0.9375
# 1764
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1814 - accuracy: 0.9375
# 1765
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3443 - accuracy: 0.9375
# 1766
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0480 - accuracy: 1.0000
# 1767
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3736 - accuracy: 0.9375
# 1768
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1374 - accuracy: 0.9688
# 1769
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1542 - accuracy: 0.9375
# 1770
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3535 - accuracy: 0.9062
# 1771
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1688 - accuracy: 0.9375
# 1772
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4007 - accuracy: 0.9375
# 1773
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1391 - accuracy: 0.9688
# 1774
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0767 - accuracy: 1.0000
# 1775
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1780 - accuracy: 0.9375
# 1776
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1047 - accuracy: 0.9688
# 1777
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 1.0000
# 1778
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1469 - accuracy: 0.9375
# 1779
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4904 - accuracy: 0.8750
# 1780
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3334 - accuracy: 0.9375
# 1781
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0989 - accuracy: 0.9688
# 1782
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2991 - accuracy: 0.8438
# 1783
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1105 - accuracy: 0.9375
# 1784
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 1.0000
# 1785
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9688
# 1786
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0529 - accuracy: 1.0000
# 1787
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 1.0000
# 1788
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9688
# 1789
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.9375
# 1790
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0531 - accuracy: 1.0000
# 1791
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0596 - accuracy: 1.0000
# 1792
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# 1793
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0857 - accuracy: 1.0000
# 1794
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 1.0000
# 1795
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1128 - accuracy: 0.9688
# 1796
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 1.0000
# 1797
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2047 - accuracy: 0.9062
# 1798
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 1.0000
# 1799
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9688
# 1800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2035 - accuracy: 0.9375
# 1801
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9228 - accuracy: 0.8125
# 1802
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0890 - accuracy: 0.9688
# 1803
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1534 - accuracy: 0.9375
# 1804
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0454 - accuracy: 0.9688
# 1805
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000
# 1806
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0877 - accuracy: 0.9688
# 1807
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# 1808
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6151 - accuracy: 0.9375
# 1809
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3773 - accuracy: 0.9062
# 1810
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0451 - accuracy: 1.0000
# 1811
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.9062
# 1812
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 1.0000
# 1813
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 1.0000
# 1814
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0777 - accuracy: 0.9688
# 1815
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4572 - accuracy: 0.9062
# 1816
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3836 - accuracy: 0.8750
# 1817
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2517 - accuracy: 0.8750
# 1818
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1099 - accuracy: 0.9375
# 1819
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.9062
# 1820
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1204 - accuracy: 0.9688
# 1821
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 0.9375
# 1822
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0980 - accuracy: 0.9688
# 1823
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1529 - accuracy: 0.9062
# 1824
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2380 - accuracy: 0.9062
# 1825
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1644 - accuracy: 0.9688
# 1826
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.9375
# 1827
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 1.0000
# 1828
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3394 - accuracy: 0.9375
# 1829
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0989 - accuracy: 0.9688
# 1830
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0602 - accuracy: 0.9688
# 1831
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2687 - accuracy: 0.9062
# 1832
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.9688
# 1833
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2302 - accuracy: 0.9375
# 1834
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3252 - accuracy: 0.9062
# 1835
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3513 - accuracy: 0.9062
# 1836
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1820 - accuracy: 0.9375
# 1837
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5870 - accuracy: 0.8750
# 1838
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1355 - accuracy: 0.9375
# 1839
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2306 - accuracy: 0.9375
# 1840
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9375
# 1841
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0625 - accuracy: 0.9688
# 1842
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 1.0000
# 1843
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2490 - accuracy: 0.8750
# 1844
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1111 - accuracy: 0.9688
# 1845
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1599 - accuracy: 0.9375
# 1846
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1440 - accuracy: 0.9688
# 1847
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.9062
# 1848
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0956 - accuracy: 0.9688
# 1849
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2230 - accuracy: 0.9688
# 1850
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9375
# 1851
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5030 - accuracy: 0.8438
# 1852
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4930 - accuracy: 0.8750
# 1853
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0723 - accuracy: 0.9688
# 1854
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.9375
# 1855
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9688
# 1856
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0585 - accuracy: 1.0000
# 1857
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 1.0000
# 1858
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9375
# 1859
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3056 - accuracy: 0.9688
# 1860
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1892 - accuracy: 0.9375
# 1861
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 1.0000
# 1862
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1142 - accuracy: 0.9375
# 1863
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1980 - accuracy: 0.9375
# 1864
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1608 - accuracy: 0.9375
# 1865
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1266 - accuracy: 0.9375
# 1866
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1616 - accuracy: 0.9688
# 1867
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1200 - accuracy: 1.0000
# 1868
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0770 - accuracy: 0.9688
# 1869
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9375
# 1870
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9375
# 1871
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4974 - accuracy: 0.8750
# 1872
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2219 - accuracy: 0.8750
# 1873
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 1.0000
# 1874
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1120 - accuracy: 0.9688
# 1875
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1361 - accuracy: 0.9595
# validation accuracy: 0.9595000147819519

# %%
#Early Stopping

# Define model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  # Design 1. L2 Parameter norm penalty by kernel regularizer:
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Define training parameters, feel free to play with the different optimizers as well.
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Load training data (reduce training data to 10k samples)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_validation, y_validation) = mnist.load_data()

# Normalize input images (comply with activation function)
x_train, x_validation = x_train / 255.0, x_validation / 255.0

# 4. Early stopping (usually you should monitor the validation accuracy)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                      min_delta=0,
                                      patience=1,
                                      mode='auto'
                                      )

# Fit model on training data (with callback)
model.fit(x_train, 
          y_train, 
          epochs=15, 
          shuffle=True, 
          callbacks=[es],
          validation_data=(x_validation, y_validation)
         )

# Evaluate performance on validation set
_, validation_acc = model.evaluate(x_validation, y_validation)
print('validation accuracy:', validation_acc)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.8984 - accuracy: 0.8446 - val_loss: 0.6312 - val_accuracy: 0.9236
# Epoch 2/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6144 - accuracy: 0.9258 - val_loss: 0.5308 - val_accuracy: 0.9332
# Epoch 3/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5290 - accuracy: 0.9345 - val_loss: 0.4839 - val_accuracy: 0.9413
# Epoch 4/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4820 - accuracy: 0.9387 - val_loss: 0.5050 - val_accuracy: 0.9232
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5050 - accuracy: 0.9232
# validation accuracy: 0.9232000112533569

# %%
# Define model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),

  # Design 0. without regularization:
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Define training parameters, feel free to play with the different optimizers as well.
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Load training data (reduce training data to 10k samples)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_validation, y_validation) = mnist.load_data()

# Normalize input images (comply with activation function)
x_train, x_validation = x_train / 255.0, x_validation / 255.0

# 4. Early stopping (usually you should monitor the validation accuracy)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                      min_delta=0,
                                      patience=1,
                                      mode='auto'
                                      )

# Fit model on training data (with callback)
model.fit(x_train, 
          y_train, 
          epochs=15, 
          shuffle=True, 
          callbacks=[es],
          validation_data=(x_validation, y_validation)
         )

# Evaluate performance on validation set
_, validation_acc = model.evaluate(x_validation, y_validation)
print('validation accuracy:', validation_acc)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3507 - accuracy: 0.8917 - val_loss: 0.1439 - val_accuracy: 0.9579
# Epoch 2/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1048 - accuracy: 0.9704 - val_loss: 0.1116 - val_accuracy: 0.9685
# Epoch 3/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0761 - accuracy: 0.9785 - val_loss: 0.0893 - val_accuracy: 0.9778
# Epoch 4/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0552 - accuracy: 0.9843 - val_loss: 0.0849 - val_accuracy: 0.9793
# Epoch 5/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0459 - accuracy: 0.9861 - val_loss: 0.0992 - val_accuracy: 0.9768
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0992 - accuracy: 0.9768
# validation accuracy: 0.9768000245094299

# %% [markdown]
# **We can use CNN's for object recognition/object detection where we can implement all the methods mentioned.**
